# %% [markdown]
# # 0. Introducción a Cron y Logger en Python
#
# ## 0.1. ¿Qué es **Cron**?
#
# https://en.wikipedia.org/wiki/Cron
#
# La utilidad de línea de comandos **cron** es un **programador de tareas** (job scheduler) en sistemas operativos basados en `Unix`. Su función es permitir a los usuarios, quienes mantienen y configuran entornos de software, programar trabajos (jobs), como comandos o scripts de shell, conocidos también como **cron jobs**, para ejecutarse periódicamente en tiempos, fechas o intervalos fijos.
#
# Cron se utiliza típicamente para automatizar tareas de mantenimiento o administración del sistema. Sin embargo, su naturaleza general lo hace útil para otras actividades, como descargar archivos desde Internet o revisar correos electrónicos a intervalos regulares.
#
# **Cron** es más adecuado para tareas repetitivas.
#
# El nombre de **cron** proviene de "Chronos", la palabra griega para tiempo.
#
# ```bash
# # * * * * * <command to execute>
# # | | | | |
# # | | | | day of the week (0–6) (Sunday to Saturday; 7 is also Sunday on some systems)
# # | | | month (1–12)
# # | | day of the month (1–31)
# # | hour (0–23)
# # minute (0–59)
# ```
#
# ### Vamos a jugar
# https://crontab.guru/

# %% [markdown]
# ## 0.2. ¿Qué es **Logger** en Python?
#
# A medida que nuestros scripts se vuelven más complejos, necesitamos una forma de **monitorear** lo que está sucediendo en ellos, especialmente cuando algo sale mal. Aquí es donde entra **logging**.
#
# `Python` tiene un módulo integrado llamado `logging` que permite registrar eventos o mensajes en diferentes niveles:
#
# - **DEBUG**: Información detallada, usualmente para desarrolladores.
# - **INFO**: Confirmación de que las cosas están funcionando como se esperaba.
# - **WARNING**: Algo inesperado, pero no crítico.
# - **ERROR**: Fallos debido a un problema en el programa.
# - **CRITICAL**: Error grave, usualmente detiene el programa.
#
# Para usar **logger** en un script de Python:

# %%
import logging

# Configuración básica de logging
logging.basicConfig(
    level=logging.INFO, 
    format='%(asctime)s - %(levelname)s - %(message)s',
)

# Ejemplo de cómo registrar eventos
logging.debug("Este es un mensaje de depuración")
logging.info("Este es un mensaje informativo")
logging.warning("Este es una advertencia")
logging.error("Este es un mensaje de error")
logging.critical("Este es un error crítico")
# Out:
# 2024-09-26 20:46:00,936 - INFO - Este es un mensaje informativo
# 2024-09-26 20:46:00,936 - WARNING - Este es una advertencia
# 2024-09-26 20:46:00,936 - ERROR - Este es un mensaje de error
# 2024-09-26 20:46:00,936 - CRITICAL - Este es un error crítico

# %% [markdown]
# ### Configuración de **Logger** en Python
#
# El módulo `logging` de Python permite una gran flexibilidad para definir cómo y dónde se registran los mensajes. Algunas de las configuraciones más comunes son:
#
# #### 1. **Nivel de Log** (`level`)
# El nivel del log define la gravedad de los mensajes que se quieren capturar. Algunos niveles de log comunes incluyen:
# - `DEBUG`: Información detallada, útil para depuración.
# - `INFO`: Confirmaciones de que el programa está funcionando como se espera.
# - `WARNING`: Indica que algo inesperado sucedió, pero el programa sigue funcionando.
# - `ERROR`: Señala errores más graves, pero que no detienen la ejecución.
# - `CRITICAL`: Errores graves que probablemente detendrán el programa.
#
# Cuando configuramos un **nivel de log**, sólo se capturan los mensajes de ese nivel o superiores. Por ejemplo, si establecemos el nivel en `WARNING`, se registrarán los mensajes `WARNING`, `ERROR` y `CRITICAL`, pero no los `DEBUG` o `INFO`.
#
# #### 2. **Formato del mensaje** (`format`)
# El formato del mensaje permite personalizar cómo se muestran los logs. Algunos componentes útiles en el formato son:
# - `%(asctime)s`: La fecha y hora en que se registró el mensaje.
# - `%(levelname)s`: El nivel del log (DEBUG, INFO, WARNING, etc.).
# - `%(message)s`: El mensaje que se ha registrado.
# - `%(name)s`: El nombre del logger.
# - `%(threadName)s`: El nombre del hilo desde donde se emitió el log.
# - `%(processName)s`: El nombre del proceso que emitió el log.
#
# #### 3. **Formato de fecha y hora** (`datefmt`)
# El parámetro `datefmt` permite personalizar el formato de la fecha y hora que se incluye en los mensajes de log. Puedes usar cualquier formato de fecha y hora compatible con Python, como el que se usa en `strftime`. Esto es útil para ajustar el formato a las necesidades específicas de tu aplicación.
#
# ##### Códigos de Formato Comunes
#
# Aquí tienes algunos códigos de formato comúnmente utilizados que puedes usar con `strftime`:
#
# | Código | Significado                           | Ejemplo de Salida       |
# |--------|---------------------------------------|--------------------------|
# | `%Y`   | Año con siglo                         | `2024`                   |
# | `%y`   | Año sin siglo (00-99)                | `24`                     |
# | `%m`   | Mes como un decimal con ceros (01-12)| `09`                     |
# | `%B`   | Nombre completo del mes               | `Septiembre`             |
# | `%b`   | Nombre abreviado del mes              | `Sep`                    |
# | `%d`   | Día del mes (01-31)                  | `24`                     |
# | `%H`   | Hora (00-23)                         | `14`                     |
# | `%I`   | Hora (01-12)                         | `02`                     |
# | `%M`   | Minuto (00-59)                       | `05`                     |
# | `%S`   | Segundo (00-59)                      | `30`                     |
# | `%p`   | AM o PM                              | `PM`                     |
# | `%A`   | Nombre completo del día de la semana | `Martes`                 |
# | `%a`   | Nombre abreviado del día de la semana | `Mar`                    |
# | `%j`   | Día del año (001-366)                | `267`                    |
# | `%U`   | Número de semana del año (00-53)     | `39`                     |
# | `%W`   | Número de semana del año (00-53), basado en lunes | `39`          |

# %%
import logging
import os

logger = logging.getLogger(__name__)
                           
logging.basicConfig(
    filename='backup.log', 
    level=logging.INFO, 
    format='%(asctime)s - %(levelname)s - %(name)s - %(message)s',
     datefmt='%Y-%m-%d %H:%M:%S',
)

def hacer_respaldo():
    try:
        # Supongamos que aquí ocurre el proceso de respaldo
        logger.info("Respaldo iniciado")
        # Simulación de respaldo
        if os.path.exists('base_de_datos.db'):
            logger.info("Respaldo exitoso")
        else:
            logger.error("Error: La base de datos no existe")
    except Exception as e:
        logger.critical(f"Error crítico durante el respaldo: {e}")

# Ejecutamos la función
hacer_respaldo()
# Out:
# 2024-09-26 20:46:00,954 - INFO - Respaldo iniciado
# 2024-09-26 20:46:00,970 - ERROR - Error: La base de datos no existe

# %% [markdown]
# Ahora sí, empecemos la clase de hoy
#
# # 1. Machine Learning Pipeline a.k.a Workflow Orchestration
#
# > Un pipeline de machine learning es una serie de pasos secuenciales y automatizados que se siguen para entrenar, evaluar y desplegar un modelo de machine learning.
# > El objetivo principal de un pipeline es automatizar el proceso repetitivo de transformar datos crudos en un modelo que pueda usarse en producción.
#
#
# ### Yo tratando de explicar el orden de ejecución de las celdas de mi `jupyter-notebook`:
#
#  <img style="display: block; margin: auto;" src="./images/orchestration-meme.png" width="580" height="50">

# %% [markdown]
# Revisemos lo que hemos hecho hasta ahora con nuestro código...
# 1. Downloading data ----> Ingestion
# 2. Transforming the data ----> Filtering, removing outliers
# 3. Preparing data for ML ----> Feature Engineering
# 4. Hyper-parameter tunning ----> Best params
# 5. Train the final model ----> Best params
# 6. Registry the final model
#
# **Problemas:**
# - Un cuaderno gigante
# - Sin muchas instrucciones
# - Poco legible para cualquier persona
# - No escalable ni mantenible
# - Podríamos decir que es un `workflow`, ya que se debe ejecutar en un orden específico

# %%
def download_data(year, month):
    ...
    return df

def prepare_data(df):
    ...
    return df

def feature_engineering(df):
    ...
    return X, y

def find_best_model(X, y):
    ...
    return params

def train_model(X, y, params):
    ...
    return model

def main():
    df = download_data(2024,1)
    df = prepare_data(df)
    X, y = feature_engineering(df)
    model_params = find_best_model(X, y)
    model = train_model(X, y, model_params)

# %% [markdown]
# Mucho mejor, no?
#
# Pero sigue teniendo problemas:
# - Lo podemos agendar?
# - Qué pasa si tengo múltiples archivos?
# - O si no lo quiero ejecutar en mi máquina local?
# - Qué pasa si una de las funciones falla? Si es solamente temporal el fallo?
# - Y si queremos notificar que ese error ocurrió a algún administrador?
#
# Hay múltiples herramientas que vienen a solventar esos problemas:
#
# - [Apache Airflow](https://airflow.apache.org/)
# - [Prefect](https://www.prefect.io/)
# - [Mage](https://www.mage.ai/)
# - [Dagster](https://dagster.io/)
# - [Kubeflow Pipelines](https://www.kubeflow.org/docs/components/pipelines/)
# - [Scikitlearn Pipelines](https://scikit-learn.org/stable/modules/compose.html#pipeline)

# %% [markdown]
# # 2. Prefect
#
# ## 2.1. Definiciones en **Prefect**
#
# ### 2.1.1. **Task (Tarea)**
# https://docs.prefect.io/3.0/develop/write-tasks
#
# En **Prefect**, una `task` es la unidad más básica de trabajo en un flujo de Prefect. Una `task` representa una operación individual que se ejecuta dentro de un flujo de trabajo (`flow`). Puedes convertir cualquier función de Python en una `task` agregando el decorador `@task`.
#
# Las tasks pueden:
# - **Tomar entradas, realizar un trabajo y devolver salidas**: Realizan operaciones con los datos que reciben y devuelven resultados.
# - **Cachear su ejecución a través de múltiples invocaciones**: Evitar repetir cálculos si una task ya se ejecutó anteriormente con los mismos inputs.
# - **Encapsular la lógica del flujo en unidades reutilizables**: Pueden ser utilizadas en diferentes flows.
# - **Usar logging automático** para capturar detalles de ejecución, etiquetas (tags) y estado final.
# - **Ejecutarse de forma concurrente**: Permiten paralelismo en la ejecución de tareas.
# - **Definirse en el mismo archivo que el `flow` o importarse de módulos**.
# - **Llamarse desde `flows` u otras `tasks`**.
#
# **Ejemplo de una tarea:**
#
# ```python
# from prefect import task
#
# @task
# def sumar(a, b):
#     return a + b
# ```

# %% [markdown]
# ### 2.1.2. **Flow (Flujo)**
# https://docs.prefect.io/3.0/develop/write-flows
#
# Un `flow` en **Prefect** es una colección de `tasks` que se ejecutan de manera organizada y coordinada.
#
# Un `flow` define cómo las `tasks` interactúan entre sí y permite orquestar la ejecución de múltiples `tasks` con reglas específicas, como dependencias, condicionales y paralelismo.
#
# Además, un `flow` puede manejar `tasks` de manera secuencial o en paralelo, así como gestionarlas en función de eventos externos.
#
# Los flows se definen como funciones en Python, y pueden tomar entradas, realizar tareas y devolver resultados. Cualquier función Python puede convertirse en un flow de Prefect añadiendo el decorador `@flow`:
# ```python
# from prefect import flow
#
# @flow
# def mi_flujo_principal():
#     resultado = sumar(3, 4)
#     print(f"El resultado es {resultado}")
# ```
# #### Capacidades de los Flows en Prefect:
#
# Cuando una función se convierte en un `flow`, adquiere las siguientes capacidades:
#
# - **Seguimiento automático de metadatos** sobre las ejecuciones del flujo, como el tiempo de ejecución y el estado final.
# - **Registro de cada estado** que el flujo alcanza, lo que permite observar y actuar sobre cada transición en la ejecución del flow.
# - **Validación de tipos de los argumentos** de entrada como parámetros del flujo de trabajo.
# - **Reintentos automáticos** en caso de fallo, con límites y retrasos configurables.
# - **Timeouts** para evitar que los flujos de trabajo se ejecuten durante demasiado tiempo sin control.
# - **Capacidad de despliegue**, lo que expone una API para interactuar con el flow de manera remota.
#
# Los `flows` se identifican de forma única por su nombre. Puedes especificar un nombre para el `flow` utilizando el parámetro `name`:
#
# ```python
# @flow(name="Mi Flujo")
# def mi_flujo() -> str:
#     return "¡Hola, mundo!"
# ```
#
# Si no proporcionas un nombre, Prefect usará el nombre de la función del flow.
#
# #### Ejecución de `Flows`:
#
# Una ejecución de flow (**flow run**) es una ejecución individual de un `flow`.
#
# Puedes ejecutar un `flow` llamándolo por su nombre de función, de la misma manera que lo harías con una función normal de `Python`. También puedes ejecutar un `flow` mediante:
#
# - **Programadores externos**, como `cron`, para invocar la función del `flow`.
# - **Desplegar el flow en Prefect Cloud** o en un servidor auto-hospedado de Prefect.
# - **Iniciar una ejecución de flow a través de un cronograma**, la interfaz de usuario de Prefect, o la API de Prefect.
#
# Sin importar cómo ejecutes el `flow`, `Prefect` monitorea su ejecución, capturando el estado para observabilidad. Además, puedes registrar una variedad de metadatos sobre las ejecuciones del flow para monitoreo, resolución de problemas y auditoría.

# %% [markdown]
# ### 2.1.3. Diferencias entre `Task` y `Flow`:
#
# - **Task**: Una tarea individual, pequeña y específica que ejecuta una operación.
# - **Flow**: Un contenedor que organiza y coordina la ejecución de varias tasks, permitiendo su orquestación.
#
# ### 2.1.4. Ejemplo Completo de Task y Flow en Prefect:
#
# ```python
# from prefect import task, flow
#
# @task
# def sumar(a, b):
#     return a + b
#
# @flow
# def mi_flujo_principal():
#     resultado = sumar(3, 4)
#     print(f"El resultado es {resultado}")
#
# # Ejecutar el flow
# mi_flujo_principal()
# ```

# %% [markdown]
# ## 2.2 Uso de `Prefect`
#
# ```bash
# pip install prefect
# prefect version
# ```
#
# Ahora vamos a inicializar un servidor de `prefect`
#
# ```bash
# prefect server start
# ```
#
# Vamos a ver un `flow` sencillo

# %%
import httpx
from prefect import flow, task


@task(retries=4, retry_delay_seconds=1, log_prints=True)
def fetch_cat_fact():
    cat_fact = httpx.get("https://f3-vyx5c2hfpq-ue.a.run.app/")
    #An endpoint that is designed to fail sporadically
    if cat_fact.status_code >= 400:
        raise Exception()
    print(cat_fact.text)


@flow
def fetch():
    fetch_cat_fact()

# %%
fetch()
# Out:
# 20:46:06.819 | INFO    | prefect - Starting server on http://127.0.0.1:8480
# 20:46:14.301 | INFO    | prefect.engine - Created flow run 'paper-buzzard' for flow 'fetch'
# 20:46:14.768 | INFO    | Task run 'fetch_cat_fact-49f' - Created task run 'fetch_cat_fact-49f' for task 'fetch_cat_fact'
# 20:46:15.685 | INFO    | Task run 'fetch_cat_fact-49f' - Task run failed with exception: Exception() - Retry 1/4 will start 1 second(s) from now
# 20:46:19.302 | INFO    | Task run 'fetch_cat_fact-49f' - Cats lose almost as much fluid in the saliva while grooming themselves as they do through urination.
# 20:46:19.302 | INFO    | Task run 'fetch_cat_fact-49f' - Finished in state Completed()
# 20:46:19.385 | INFO    | Flow run 'paper-buzzard' - Finished in state Completed()

# %% [markdown]
# Ahora veamos el concepto de `subflows`

# %%
from prefect import flow


@flow(name="Cat fact")
def fetch_cat_fact():
    """A flow that gets a cat fact"""
    return httpx.get("https://catfact.ninja/fact?max_length=140").json()["fact"]


@flow(name="Dog fact")
def fetch_dog_fact():
    """A flow that gets a dog fact"""
    return httpx.get(
        "https://dogapi.dog/api/v2/facts",
        headers={"accept": "application/json"},
    ).json()["data"][0]["attributes"]["body"]


@flow(name="Animals fact", log_prints=True)
def animal_facts():
    cat_fact = fetch_cat_fact()
    dog_fact = fetch_dog_fact()
    print(f"🐱: {cat_fact} \n🐶: {dog_fact}")

# %%
animal_facts()
# Out:
# 20:46:19.835 | INFO    | prefect.engine - Created flow run 'tacky-adder' for flow 'Animals fact'
# 20:46:20.352 | INFO    | Flow run 'tacky-adder' - Created subflow run 'amigurumi-scorpion' for flow 'Cat fact'
# 20:46:21.153 | INFO    | Flow run 'amigurumi-scorpion' - Finished in state Completed()
# 20:46:21.619 | INFO    | Flow run 'tacky-adder' - Created subflow run 'just-toucanet' for flow 'Dog fact'
# 20:46:22.785 | INFO    | Flow run 'just-toucanet' - Finished in state Completed()
# 20:46:22.785 | INFO    | Flow run 'tacky-adder' - 🐱: In Ancient Egypt, when a person's house cat passed away, the owner would shave their eyebrows to reflect their grief.
# 🐶: The U.S. has the highest dog population in the world.
# 20:46:22.835 | INFO    | Flow run 'tacky-adder' - Finished in state Completed()

# %% [markdown]
# Ahora vamos a hacerlo para nuestro pipeline de entrenamiento en nuestro proyecto `nyc-taxi-time-prediction`
#
# - Vamos a crear una nueva rama `feat/training_orchestration`.
# - Vamos a crear un nuevo directorio `training pipeline`
# - crear un archivo llamado `train.py`

# %%
import pickle
import mlflow
import pathlib
import dagshub
import pandas as pd
import xgboost as xgb
from hyperopt.pyll import scope
from sklearn.metrics import root_mean_squared_error
from sklearn.feature_extraction import DictVectorizer
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials


def read_data(file_path: str) -> pd.DataFrame:
    """Read data into DataFrame"""
    df = pd.read_parquet(file_path)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df["duration"] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ["PULocationID", "DOLocationID"]
    df[categorical] = df[categorical].astype(str)

    return df

def add_features(df_train: pd.DataFrame, df_val: pd.DataFrame):
    """Add features to the model"""
    df_train["PU_DO"] = df_train["PULocationID"] + "_" + df_train["DOLocationID"]
    df_val["PU_DO"] = df_val["PULocationID"] + "_" + df_val["DOLocationID"]

    categorical = ["PU_DO"]  #'PULocationID', 'DOLocationID']
    numerical = ["trip_distance"]

    dv = DictVectorizer()

    train_dicts = df_train[categorical + numerical].to_dict(orient="records")
    X_train = dv.fit_transform(train_dicts)

    val_dicts = df_val[categorical + numerical].to_dict(orient="records")
    X_val = dv.transform(val_dicts)

    y_train = df_train["duration"].values
    y_val = df_val["duration"].values
    return X_train, X_val, y_train, y_val, dv

def hyper_parameter_tunning(X_train, X_val, y_train, y_val, dv):
    
    mlflow.xgboost.autolog()
    
    training_dataset = mlflow.data.from_numpy(X_train.data, targets=y_train, name="green_tripdata_2024-01")
    
    validation_dataset = mlflow.data.from_numpy(X_val.data, targets=y_val, name="green_tripdata_2024-02")
    
    train = xgb.DMatrix(X_train, label=y_train)
    
    valid = xgb.DMatrix(X_val, label=y_val)
    
    def objective(params):
        with mlflow.start_run(nested=True):
             
            # Tag model
            mlflow.set_tag("model_family", "xgboost")
            
            # Train model
            booster = xgb.train(
                params=params,
                dtrain=train,
                num_boost_round=100,
                evals=[(valid, 'validation')],
                early_stopping_rounds=10
            )
            
            # Predict in the val dataset
            y_pred = booster.predict(valid)
            
            # Calculate metric
            rmse = root_mean_squared_error(y_val, y_pred)
            
            # Log performance metric
            mlflow.log_metric("rmse", rmse)
    
        return {'loss': rmse, 'status': STATUS_OK}

    with mlflow.start_run(run_name="Xgboost Hyper-parameter Optimization", nested=True):
        search_space = {
            'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
            'learning_rate': hp.loguniform('learning_rate', -3, 0),
            'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
            'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
            'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
            'objective': 'reg:squarederror',
            'seed': 42
        }
        
        best_params = fmin(
            fn=objective,
            space=search_space,
            algo=tpe.suggest,
            max_evals=10,
            trials=Trials()
        )
        best_params["max_depth"] = int(best_params["max_depth"])
        best_params["seed"] = 42
        best_params["objective"] = "reg:squarederror"
        
        mlflow.log_params(best_params)

    return best_params


def train_best_model(X_train, X_val, y_train, y_val, dv, best_params) -> None:
    """train a model with best hyperparams and write everything out"""

    with mlflow.start_run(run_name="Best model ever"):
        train = xgb.DMatrix(X_train, label=y_train)
        valid = xgb.DMatrix(X_val, label=y_val)

        mlflow.log_params(best_params)

        # Log a fit model instance
        booster = xgb.train(
            params=best_params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, 'validation')],
            early_stopping_rounds=10
        )

        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

        pathlib.Path("models").mkdir(exist_ok=True)
        with open("models/preprocessor.b", "wb") as f_out:
            pickle.dump(dv, f_out)
        
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
    
    return None

def main_flow(year: int, month_train: str, month_val: str) -> None:
    """The main training pipeline"""
    
    train_path = f"../data/green_tripdata_{year}-{month_train}.parquet"
    val_path = f"../data/green_tripdata_{year}-{month_val}.parquet"
    
    # MLflow settings
    dagshub.init(url="https://dagshub.com/luislopez3105/DagsTry", mlflow=True)
    
    MLFLOW_TRACKING_URI = mlflow.get_tracking_uri()
    
    mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
    mlflow.set_experiment(experiment_name="nyc-taxi-experiment-prefect")

    # Load
    df_train = read_data(train_path)
    df_val = read_data(val_path)

    # Transform
    X_train, X_val, y_train, y_val, dv = add_features(df_train, df_val)
    
    # Hyper-parameter Tunning
    best_params = hyper_parameter_tunning(X_train, X_val, y_train, y_val, dv)
    
    # Train
    train_best_model(X_train, X_val, y_train, y_val, dv, best_params)
main_flow(year="2024",month_train='01',month_val='02')
# Out:
# Accessing as luislopez3105
# Initialized MLflow to track repo "luislopez3105/DagsTry"
# Repository luislopez3105/DagsTry initialized!
# [0]	validation-rmse:8.22014
# [1]	validation-rmse:7.52278
# [2]	validation-rmse:6.98424
# [3]	validation-rmse:6.57495
# [4]	validation-rmse:6.26651
# [5]	validation-rmse:6.03648
# [6]	validation-rmse:5.86631
# [7]	validation-rmse:5.74229
# [8]	validation-rmse:5.65215
# [9]	validation-rmse:5.58614
# [10]	validation-rmse:5.53580
# [11]	validation-rmse:5.49788
# [12]	validation-rmse:5.46952
# [13]	validation-rmse:5.44914
# [14]	validation-rmse:5.43056
# [15]	validation-rmse:5.41602
# [16]	validation-rmse:5.40431
# [17]	validation-rmse:5.39518
# [18]	validation-rmse:5.38834
# [19]	validation-rmse:5.38194
# [20]	validation-rmse:5.37744
# [21]	validation-rmse:5.37370
# [22]	validation-rmse:5.37066
# [23]	validation-rmse:5.36700
# [24]	validation-rmse:5.36416
# [25]	validation-rmse:5.36092
# [26]	validation-rmse:5.35703
# [27]	validation-rmse:5.35357
# [28]	validation-rmse:5.35079
# [29]	validation-rmse:5.34856
# [30]	validation-rmse:5.34569
# [31]	validation-rmse:5.34347
# [32]	validation-rmse:5.34218
# [33]	validation-rmse:5.34134
# [34]	validation-rmse:5.33989
# [35]	validation-rmse:5.33898
# [36]	validation-rmse:5.33830
# [37]	validation-rmse:5.33754
# [38]	validation-rmse:5.33542
# [39]	validation-rmse:5.33460
# [40]	validation-rmse:5.33252
# [41]	validation-rmse:5.33140
# [42]	validation-rmse:5.33023
# [43]	validation-rmse:5.32929
# [44]	validation-rmse:5.32883
# [45]	validation-rmse:5.32792
# [46]	validation-rmse:5.32728
# [47]	validation-rmse:5.32662
# [48]	validation-rmse:5.32592
# [49]	validation-rmse:5.32533
# [50]	validation-rmse:5.32506
# [51]	validation-rmse:5.32427
# [52]	validation-rmse:5.32376
# [53]	validation-rmse:5.32299
# [54]	validation-rmse:5.32239
# [55]	validation-rmse:5.32165
# [56]	validation-rmse:5.32116
# [57]	validation-rmse:5.32068
# [58]	validation-rmse:5.32024
# [59]	validation-rmse:5.31974
# [60]	validation-rmse:5.31918
# [61]	validation-rmse:5.31851
# [62]	validation-rmse:5.31751
# [63]	validation-rmse:5.31712
# [64]	validation-rmse:5.31687
# [65]	validation-rmse:5.31657
# [66]	validation-rmse:5.31603
# [67]	validation-rmse:5.31549
# [68]	validation-rmse:5.31543
# [69]	validation-rmse:5.31498
# [70]	validation-rmse:5.31458
# [71]	validation-rmse:5.31381
# [72]	validation-rmse:5.31380
# [73]	validation-rmse:5.31383
# [74]	validation-rmse:5.31310
# [75]	validation-rmse:5.31258
# [76]	validation-rmse:5.31249
# [77]	validation-rmse:5.31182
# [78]	validation-rmse:5.31193
# [79]	validation-rmse:5.31167
# [80]	validation-rmse:5.31124
# [81]	validation-rmse:5.31043
# [82]	validation-rmse:5.31009
# [83]	validation-rmse:5.30987
# [84]	validation-rmse:5.30954
# [85]	validation-rmse:5.30896
# [86]	validation-rmse:5.30831
# [87]	validation-rmse:5.30808
# [88]	validation-rmse:5.30791
# [89]	validation-rmse:5.30763
# [90]	validation-rmse:5.30751
# [91]	validation-rmse:5.30702
# [92]	validation-rmse:5.30655
# [93]	validation-rmse:5.30627
# [94]	validation-rmse:5.30603
# [95]	validation-rmse:5.30583
# [96]	validation-rmse:5.30553
# [97]	validation-rmse:5.30549
# [98]	validation-rmse:5.30508
# [99]	validation-rmse:5.30448
#   0%|          | 0/10 [00:10<?, ?trial/s, best loss=?]
# 2024/09/26 20:46:42 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:46:42] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/26 20:46:55 INFO mlflow.tracking._tracking_service.client: 🏃 View run resilient-robin-986 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/18fb3d5b341c4ee8bc2d9edcf651c442.
#
# 2024/09/26 20:46:55 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:6.57059
# [1]	validation-rmse:5.67775
# [2]	validation-rmse:5.40509
# [3]	validation-rmse:5.32129
# [4]	validation-rmse:5.29132
# [5]	validation-rmse:5.27507
# [6]	validation-rmse:5.26310
# [7]	validation-rmse:5.25689
# [8]	validation-rmse:5.24829
# [9]	validation-rmse:5.23859
# [10]	validation-rmse:5.23544
# [11]	validation-rmse:5.23247
# [12]	validation-rmse:5.23142
# [13]	validation-rmse:5.22987
# [14]	validation-rmse:5.22710
# [15]	validation-rmse:5.21912
# [16]	validation-rmse:5.21910
# [17]	validation-rmse:5.21665
# [18]	validation-rmse:5.21462
# [19]	validation-rmse:5.20693
# [20]	validation-rmse:5.20471
# [21]	validation-rmse:5.20395
# [22]	validation-rmse:5.20214
# [23]	validation-rmse:5.20270
# [24]	validation-rmse:5.20082
# [25]	validation-rmse:5.20119
# [26]	validation-rmse:5.20209
# [27]	validation-rmse:5.20244
# [28]	validation-rmse:5.20337
# [29]	validation-rmse:5.20222
# [30]	validation-rmse:5.20356
# [31]	validation-rmse:5.20153
# [32]	validation-rmse:5.20284
# [33]	validation-rmse:5.20171
# [34]	validation-rmse:5.20235
#  10%|█         | 1/10 [00:39<04:10, 27.84s/trial, best loss: 5.304482466973026]
# 2024/09/26 20:47:13 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:47:13] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/26 20:47:21 INFO mlflow.tracking._tracking_service.client: 🏃 View run victorious-mole-450 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/cebc9620857943e3ac8f81979c329a93.
#
# 2024/09/26 20:47:21 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:6.64780
# [1]	validation-rmse:5.76118
# [2]	validation-rmse:5.47917
# [3]	validation-rmse:5.39390
# [4]	validation-rmse:5.35323
# [5]	validation-rmse:5.33551
# [6]	validation-rmse:5.32988
# [7]	validation-rmse:5.31756
# [8]	validation-rmse:5.31489
# [9]	validation-rmse:5.31005
# [10]	validation-rmse:5.30737
# [11]	validation-rmse:5.30638
# [12]	validation-rmse:5.30643
# [13]	validation-rmse:5.30452
# [14]	validation-rmse:5.30595
# [15]	validation-rmse:5.30467
# [16]	validation-rmse:5.30387
# [17]	validation-rmse:5.29936
# [18]	validation-rmse:5.29921
# [19]	validation-rmse:5.29896
# [20]	validation-rmse:5.29854
# [21]	validation-rmse:5.29834
# [22]	validation-rmse:5.29682
# [23]	validation-rmse:5.29597
# [24]	validation-rmse:5.29683
# [25]	validation-rmse:5.29588
# [26]	validation-rmse:5.29472
# [27]	validation-rmse:5.29386
# [28]	validation-rmse:5.29307
# [29]	validation-rmse:5.29217
# [30]	validation-rmse:5.29314
# [31]	validation-rmse:5.29357
# [32]	validation-rmse:5.29366
# [33]	validation-rmse:5.29407
# [34]	validation-rmse:5.29445
# [35]	validation-rmse:5.29652
# [36]	validation-rmse:5.29514
# [37]	validation-rmse:5.29583
# [38]	validation-rmse:5.29685
# [39]	validation-rmse:5.29762
#  20%|██        | 2/10 [01:07<03:34, 26.79s/trial, best loss: 5.202350808032581]
# 2024/09/26 20:47:52 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:47:52] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/26 20:47:59 INFO mlflow.tracking._tracking_service.client: 🏃 View run dashing-skunk-532 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/6a0a8d8adcf84aee80ce4647bb9b2145.
#
# 2024/09/26 20:47:59 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:8.73337
# [1]	validation-rmse:8.38992
# [2]	validation-rmse:8.07854
# [3]	validation-rmse:7.79678
# [4]	validation-rmse:7.54240
# [5]	validation-rmse:7.31331
# [6]	validation-rmse:7.10748
# [7]	validation-rmse:6.92315
# [8]	validation-rmse:6.75810
# [9]	validation-rmse:6.61041
# [10]	validation-rmse:6.47848
# [11]	validation-rmse:6.36114
# [12]	validation-rmse:6.25677
# [13]	validation-rmse:6.16397
# [14]	validation-rmse:6.08191
# [15]	validation-rmse:6.00975
# [16]	validation-rmse:5.94584
# [17]	validation-rmse:5.88914
# [18]	validation-rmse:5.83900
# [19]	validation-rmse:5.79497
# [20]	validation-rmse:5.75601
# [21]	validation-rmse:5.72173
# [22]	validation-rmse:5.69119
# [23]	validation-rmse:5.66455
# [24]	validation-rmse:5.64090
# [25]	validation-rmse:5.61937
# [26]	validation-rmse:5.59979
# [27]	validation-rmse:5.58310
# [28]	validation-rmse:5.56762
# [29]	validation-rmse:5.55383
# [30]	validation-rmse:5.54137
# [31]	validation-rmse:5.53037
# [32]	validation-rmse:5.52044
# [33]	validation-rmse:5.51167
# [34]	validation-rmse:5.50300
# [35]	validation-rmse:5.49505
# [36]	validation-rmse:5.48840
# [37]	validation-rmse:5.48267
# [38]	validation-rmse:5.47668
# [39]	validation-rmse:5.47121
# [40]	validation-rmse:5.46617
# [41]	validation-rmse:5.46137
# [42]	validation-rmse:5.45715
# [43]	validation-rmse:5.45344
# [44]	validation-rmse:5.45009
# [45]	validation-rmse:5.44715
# [46]	validation-rmse:5.44451
# [47]	validation-rmse:5.44195
# [48]	validation-rmse:5.43978
# [49]	validation-rmse:5.43759
# [50]	validation-rmse:5.43534
# [51]	validation-rmse:5.43363
# [52]	validation-rmse:5.43177
# [53]	validation-rmse:5.43017
# [54]	validation-rmse:5.42830
# [55]	validation-rmse:5.42710
# [56]	validation-rmse:5.42483
# [57]	validation-rmse:5.42337
# [58]	validation-rmse:5.42221
# [59]	validation-rmse:5.42133
# [60]	validation-rmse:5.42020
# [61]	validation-rmse:5.41836
# [62]	validation-rmse:5.41724
# [63]	validation-rmse:5.41627
# [64]	validation-rmse:5.41541
# [65]	validation-rmse:5.41181
# [66]	validation-rmse:5.40912
# [67]	validation-rmse:5.40644
# [68]	validation-rmse:5.40273
# [69]	validation-rmse:5.40067
# [70]	validation-rmse:5.39877
# [71]	validation-rmse:5.39520
# [72]	validation-rmse:5.39332
# [73]	validation-rmse:5.39144
# [74]	validation-rmse:5.38868
# [75]	validation-rmse:5.38782
# [76]	validation-rmse:5.38703
# [77]	validation-rmse:5.38631
# [78]	validation-rmse:5.38506
# [79]	validation-rmse:5.38446
# [80]	validation-rmse:5.38326
# [81]	validation-rmse:5.38271
# [82]	validation-rmse:5.38221
# [83]	validation-rmse:5.38110
# [84]	validation-rmse:5.38067
# [85]	validation-rmse:5.38026
# [86]	validation-rmse:5.37815
# [87]	validation-rmse:5.37774
# [88]	validation-rmse:5.37727
# [89]	validation-rmse:5.37653
# [90]	validation-rmse:5.37622
# [91]	validation-rmse:5.37542
# [92]	validation-rmse:5.37496
# [93]	validation-rmse:5.37475
# [94]	validation-rmse:5.37446
# [95]	validation-rmse:5.37420
# [96]	validation-rmse:5.37355
# [97]	validation-rmse:5.37315
# [98]	validation-rmse:5.37294
# [99]	validation-rmse:5.37246
#  30%|███       | 3/10 [01:39<03:45, 32.19s/trial, best loss: 5.202350808032581]
# 2024/09/26 20:48:09 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:48:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/26 20:48:16 INFO mlflow.tracking._tracking_service.client: 🏃 View run nervous-crab-910 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/d5c6401571ae4bf191e00626f9a69050.
#
# 2024/09/26 20:48:16 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:5.81746
# [1]	validation-rmse:5.42439
# [2]	validation-rmse:5.34844
# [3]	validation-rmse:5.33132
# [4]	validation-rmse:5.32424
# [5]	validation-rmse:5.32280
# [6]	validation-rmse:5.31918
# [7]	validation-rmse:5.31191
# [8]	validation-rmse:5.30447
# [9]	validation-rmse:5.29904
# [10]	validation-rmse:5.29380
# [11]	validation-rmse:5.28780
# [12]	validation-rmse:5.28200
# [13]	validation-rmse:5.28013
# [14]	validation-rmse:5.25849
# [15]	validation-rmse:5.24773
# [16]	validation-rmse:5.24609
# [17]	validation-rmse:5.24593
# [18]	validation-rmse:5.24254
# [19]	validation-rmse:5.23661
# [20]	validation-rmse:5.23600
# [21]	validation-rmse:5.23498
# [22]	validation-rmse:5.23241
# [23]	validation-rmse:5.22884
# [24]	validation-rmse:5.22870
# [25]	validation-rmse:5.22888
# [26]	validation-rmse:5.23149
# [27]	validation-rmse:5.22729
# [28]	validation-rmse:5.22004
# [29]	validation-rmse:5.21835
# [30]	validation-rmse:5.21688
# [31]	validation-rmse:5.20947
# [32]	validation-rmse:5.21035
# [33]	validation-rmse:5.19436
# [34]	validation-rmse:5.19249
# [35]	validation-rmse:5.19230
# [36]	validation-rmse:5.19007
# [37]	validation-rmse:5.19051
# [38]	validation-rmse:5.18953
# [39]	validation-rmse:5.18984
# [40]	validation-rmse:5.18895
# [41]	validation-rmse:5.18998
# [42]	validation-rmse:5.18742
# [43]	validation-rmse:5.18730
# [44]	validation-rmse:5.18795
# [45]	validation-rmse:5.18731
# [46]	validation-rmse:5.18296
# [47]	validation-rmse:5.18275
# [48]	validation-rmse:5.18226
# [49]	validation-rmse:5.18220
# [50]	validation-rmse:5.18212
# [51]	validation-rmse:5.17883
# [52]	validation-rmse:5.17879
# [53]	validation-rmse:5.17886
# [54]	validation-rmse:5.17791
# [55]	validation-rmse:5.17762
# [56]	validation-rmse:5.17695
# [57]	validation-rmse:5.17812
# [58]	validation-rmse:5.17889
# [59]	validation-rmse:5.17810
# [60]	validation-rmse:5.17895
# [61]	validation-rmse:5.17851
# [62]	validation-rmse:5.17784
# [63]	validation-rmse:5.17536
# [64]	validation-rmse:5.17588
# [65]	validation-rmse:5.17618
# [66]	validation-rmse:5.17553
# [67]	validation-rmse:5.17719
# [68]	validation-rmse:5.17719
# [69]	validation-rmse:5.17705
# [70]	validation-rmse:5.17190
# [71]	validation-rmse:5.17341
# [72]	validation-rmse:5.17381
# [73]	validation-rmse:5.17326
# [74]	validation-rmse:5.17188
# [75]	validation-rmse:5.17156
# [76]	validation-rmse:5.17121
# [77]	validation-rmse:5.17118
# [78]	validation-rmse:5.17198
# [79]	validation-rmse:5.17113
# [80]	validation-rmse:5.17195
# [81]	validation-rmse:5.17199
# [82]	validation-rmse:5.17251
# [83]	validation-rmse:5.17219
# [84]	validation-rmse:5.16933
# [85]	validation-rmse:5.16970
# [86]	validation-rmse:5.16980
# [87]	validation-rmse:5.16989
# [88]	validation-rmse:5.16937
# [89]	validation-rmse:5.16954
# [90]	validation-rmse:5.16991
# [91]	validation-rmse:5.17197
# [92]	validation-rmse:5.17283
# [93]	validation-rmse:5.17289
# [94]	validation-rmse:5.17338
#  40%|████      | 4/10 [01:53<02:36, 26.13s/trial, best loss: 5.202350808032581]
# 2024/09/26 20:48:27 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:48:27] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/26 20:48:34 INFO mlflow.tracking._tracking_service.client: 🏃 View run lyrical-bat-791 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/0c6f0c7683fb4b2cbdb6b938f8eff505.
#
# 2024/09/26 20:48:34 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:8.69033
# [1]	validation-rmse:8.31093
# [2]	validation-rmse:7.96936
# [3]	validation-rmse:7.66216
# [4]	validation-rmse:7.38816
# [5]	validation-rmse:7.14322
# [6]	validation-rmse:6.92516
# [7]	validation-rmse:6.73160
# [8]	validation-rmse:6.56014
# [9]	validation-rmse:6.40809
# [10]	validation-rmse:6.27395
# [11]	validation-rmse:6.15514
# [12]	validation-rmse:6.05065
# [13]	validation-rmse:5.95903
# [14]	validation-rmse:5.87870
# [15]	validation-rmse:5.80792
# [16]	validation-rmse:5.74659
# [17]	validation-rmse:5.69267
# [18]	validation-rmse:5.64512
# [19]	validation-rmse:5.60354
# [20]	validation-rmse:5.56710
# [21]	validation-rmse:5.53548
# [22]	validation-rmse:5.50749
# [23]	validation-rmse:5.48309
# [24]	validation-rmse:5.46180
# [25]	validation-rmse:5.44318
# [26]	validation-rmse:5.42655
# [27]	validation-rmse:5.41232
# [28]	validation-rmse:5.39996
# [29]	validation-rmse:5.38869
# [30]	validation-rmse:5.37873
# [31]	validation-rmse:5.36980
# [32]	validation-rmse:5.36196
# [33]	validation-rmse:5.35496
# [34]	validation-rmse:5.34895
# [35]	validation-rmse:5.34361
# [36]	validation-rmse:5.33862
# [37]	validation-rmse:5.33399
# [38]	validation-rmse:5.32971
# [39]	validation-rmse:5.32614
# [40]	validation-rmse:5.32278
# [41]	validation-rmse:5.31925
# [42]	validation-rmse:5.31648
# [43]	validation-rmse:5.31411
# [44]	validation-rmse:5.31183
# [45]	validation-rmse:5.30916
# [46]	validation-rmse:5.30691
# [47]	validation-rmse:5.30506
# [48]	validation-rmse:5.30323
# [49]	validation-rmse:5.30138
# [50]	validation-rmse:5.29991
# [51]	validation-rmse:5.29851
# [52]	validation-rmse:5.29740
# [53]	validation-rmse:5.29603
# [54]	validation-rmse:5.29490
# [55]	validation-rmse:5.29377
# [56]	validation-rmse:5.29263
# [57]	validation-rmse:5.29137
# [58]	validation-rmse:5.29055
# [59]	validation-rmse:5.28911
# [60]	validation-rmse:5.28853
# [61]	validation-rmse:5.28712
# [62]	validation-rmse:5.28556
# [63]	validation-rmse:5.28461
# [64]	validation-rmse:5.28403
# [65]	validation-rmse:5.28297
# [66]	validation-rmse:5.28229
# [67]	validation-rmse:5.28113
# [68]	validation-rmse:5.28051
# [69]	validation-rmse:5.27802
# [70]	validation-rmse:5.27771
# [71]	validation-rmse:5.27507
# [72]	validation-rmse:5.27313
# [73]	validation-rmse:5.27291
# [74]	validation-rmse:5.27269
# [75]	validation-rmse:5.27229
# [76]	validation-rmse:5.27225
# [77]	validation-rmse:5.27060
# [78]	validation-rmse:5.26922
# [79]	validation-rmse:5.26772
# [80]	validation-rmse:5.26744
# [81]	validation-rmse:5.26662
# [82]	validation-rmse:5.26592
# [83]	validation-rmse:5.26522
# [84]	validation-rmse:5.26435
# [85]	validation-rmse:5.26342
# [86]	validation-rmse:5.26270
# [87]	validation-rmse:5.26218
# [88]	validation-rmse:5.26214
# [89]	validation-rmse:5.26126
# [90]	validation-rmse:5.26077
# [91]	validation-rmse:5.25958
# [92]	validation-rmse:5.25914
# [93]	validation-rmse:5.25819
# [94]	validation-rmse:5.25763
# [95]	validation-rmse:5.25711
# [96]	validation-rmse:5.25684
# [97]	validation-rmse:5.25528
# [98]	validation-rmse:5.25506
# [99]	validation-rmse:5.25370
#  50%|█████     | 5/10 [02:15<01:56, 23.29s/trial, best loss: 5.173379212065781]
# 2024/09/26 20:48:47 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:48:47] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/26 20:48:56 INFO mlflow.tracking._tracking_service.client: 🏃 View run traveling-sloth-701 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/53962fa8cee848ff8f20ba9add80d225.
#
# 2024/09/26 20:48:56 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:7.72416
# [1]	validation-rmse:6.82253
# [2]	validation-rmse:6.24995
# [3]	validation-rmse:5.89662
# [4]	validation-rmse:5.68574
# [5]	validation-rmse:5.55637
# [6]	validation-rmse:5.47663
# [7]	validation-rmse:5.42861
# [8]	validation-rmse:5.39613
# [9]	validation-rmse:5.37647
# [10]	validation-rmse:5.36272
# [11]	validation-rmse:5.35083
# [12]	validation-rmse:5.34209
# [13]	validation-rmse:5.33797
# [14]	validation-rmse:5.33204
# [15]	validation-rmse:5.32800
# [16]	validation-rmse:5.32253
# [17]	validation-rmse:5.32108
# [18]	validation-rmse:5.31862
# [19]	validation-rmse:5.31726
# [20]	validation-rmse:5.31517
# [21]	validation-rmse:5.31337
# [22]	validation-rmse:5.31112
# [23]	validation-rmse:5.30957
# [24]	validation-rmse:5.30755
# [25]	validation-rmse:5.30566
# [26]	validation-rmse:5.30409
# [27]	validation-rmse:5.30242
# [28]	validation-rmse:5.30079
# [29]	validation-rmse:5.29991
# [30]	validation-rmse:5.29859
# [31]	validation-rmse:5.29684
# [32]	validation-rmse:5.29628
# [33]	validation-rmse:5.29525
# [34]	validation-rmse:5.29441
# [35]	validation-rmse:5.29325
# [36]	validation-rmse:5.29239
# [37]	validation-rmse:5.29146
# [38]	validation-rmse:5.29024
# [39]	validation-rmse:5.28893
# [40]	validation-rmse:5.28821
# [41]	validation-rmse:5.28764
# [42]	validation-rmse:5.28635
# [43]	validation-rmse:5.28535
# [44]	validation-rmse:5.28363
# [45]	validation-rmse:5.28307
# [46]	validation-rmse:5.28238
# [47]	validation-rmse:5.28115
# [48]	validation-rmse:5.27980
# [49]	validation-rmse:5.27909
# [50]	validation-rmse:5.27842
# [51]	validation-rmse:5.27766
# [52]	validation-rmse:5.27728
# [53]	validation-rmse:5.27540
# [54]	validation-rmse:5.27474
# [55]	validation-rmse:5.27463
# [56]	validation-rmse:5.27401
# [57]	validation-rmse:5.27335
# [58]	validation-rmse:5.26538
# [59]	validation-rmse:5.26530
# [60]	validation-rmse:5.26470
# [61]	validation-rmse:5.26321
# [62]	validation-rmse:5.26313
# [63]	validation-rmse:5.26252
# [64]	validation-rmse:5.26211
# [65]	validation-rmse:5.26153
# [66]	validation-rmse:5.26171
# [67]	validation-rmse:5.26167
# [68]	validation-rmse:5.26105
# [69]	validation-rmse:5.26002
# [70]	validation-rmse:5.25932
# [71]	validation-rmse:5.25910
# [72]	validation-rmse:5.25851
# [73]	validation-rmse:5.25831
# [74]	validation-rmse:5.25762
# [75]	validation-rmse:5.25721
# [76]	validation-rmse:5.25654
# [77]	validation-rmse:5.25590
# [78]	validation-rmse:5.25580
# [79]	validation-rmse:5.25194
# [80]	validation-rmse:5.25103
# [81]	validation-rmse:5.25003
# [82]	validation-rmse:5.24958
# [83]	validation-rmse:5.24904
# [84]	validation-rmse:5.24675
# [85]	validation-rmse:5.24647
# [86]	validation-rmse:5.24591
# [87]	validation-rmse:5.24565
# [88]	validation-rmse:5.24580
# [89]	validation-rmse:5.24500
# [90]	validation-rmse:5.24476
# ...
# [69]	validation-rmse:5.32048
# [70]	validation-rmse:5.31979
# [71]	validation-rmse:5.31892
# [72]	validation-rmse:5.31655
# [73]	validation-rmse:5.31413
# [74]	validation-rmse:5.31242
# [75]	validation-rmse:5.31046
# [76]	validation-rmse:5.30833
# [77]	validation-rmse:5.30682
# [78]	validation-rmse:5.30540
# [79]	validation-rmse:5.30345
# [80]	validation-rmse:5.30289
# [81]	validation-rmse:5.30167
# [82]	validation-rmse:5.30122
# [83]	validation-rmse:5.30000
# [84]	validation-rmse:5.29873
# [85]	validation-rmse:5.29844
# [86]	validation-rmse:5.29757
# [87]	validation-rmse:5.29727
# [88]	validation-rmse:5.29636
# [89]	validation-rmse:5.29613
# [90]	validation-rmse:5.29497
# [91]	validation-rmse:5.29485
# [92]	validation-rmse:5.29444
# [93]	validation-rmse:5.29415
# [94]	validation-rmse:5.29349
# [95]	validation-rmse:5.29328
# [96]	validation-rmse:5.29278
# [97]	validation-rmse:5.29264
# [98]	validation-rmse:5.29244
# [99]	validation-rmse:5.29221
#  80%|████████  | 8/10 [03:27<00:40, 20.02s/trial, best loss: 5.173379212065781]
# 2024/09/26 20:49:59 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:49:59] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/26 20:50:07 INFO mlflow.tracking._tracking_service.client: 🏃 View run efficient-stoat-264 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/fc71b4f1acef47df8b562067ab3771b2.
#
# 2024/09/26 20:50:07 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:8.17518
# [1]	validation-rmse:7.44158
# [2]	validation-rmse:6.87552
# [3]	validation-rmse:6.44311
# [4]	validation-rmse:6.11907
# [5]	validation-rmse:5.87875
# [6]	validation-rmse:5.70287
# [7]	validation-rmse:5.57441
# [8]	validation-rmse:5.48160
# [9]	validation-rmse:5.41500
# [10]	validation-rmse:5.36684
# [11]	validation-rmse:5.33396
# [12]	validation-rmse:5.30939
# [13]	validation-rmse:5.29085
# [14]	validation-rmse:5.27781
# [15]	validation-rmse:5.26682
# [16]	validation-rmse:5.25783
# [17]	validation-rmse:5.25089
# [18]	validation-rmse:5.24617
# [19]	validation-rmse:5.24253
# [20]	validation-rmse:5.23893
# [21]	validation-rmse:5.23595
# [22]	validation-rmse:5.23452
# [23]	validation-rmse:5.23270
# [24]	validation-rmse:5.23121
# [25]	validation-rmse:5.22990
# [26]	validation-rmse:5.22888
# [27]	validation-rmse:5.22792
# [28]	validation-rmse:5.22788
# [29]	validation-rmse:5.22529
# [30]	validation-rmse:5.22202
# [31]	validation-rmse:5.22247
# [32]	validation-rmse:5.22188
# [33]	validation-rmse:5.22189
# [34]	validation-rmse:5.22276
# [35]	validation-rmse:5.22138
# [36]	validation-rmse:5.22122
# [37]	validation-rmse:5.22065
# [38]	validation-rmse:5.21806
# [39]	validation-rmse:5.21774
# [40]	validation-rmse:5.21554
# [41]	validation-rmse:5.21494
# [42]	validation-rmse:5.21504
# [43]	validation-rmse:5.21361
# [44]	validation-rmse:5.21301
# [45]	validation-rmse:5.21249
# [46]	validation-rmse:5.21261
# [47]	validation-rmse:5.21196
# [48]	validation-rmse:5.20984
# [49]	validation-rmse:5.20987
# [50]	validation-rmse:5.21044
# [51]	validation-rmse:5.20993
# [52]	validation-rmse:5.20909
# [53]	validation-rmse:5.20890
# [54]	validation-rmse:5.20879
# [55]	validation-rmse:5.20888
# [56]	validation-rmse:5.20849
# [57]	validation-rmse:5.20852
# [58]	validation-rmse:5.20816
# [59]	validation-rmse:5.20741
# [60]	validation-rmse:5.20655
# [61]	validation-rmse:5.20678
# [62]	validation-rmse:5.20682
# [63]	validation-rmse:5.20655
# [64]	validation-rmse:5.20622
# [65]	validation-rmse:5.20575
# [66]	validation-rmse:5.20581
# [67]	validation-rmse:5.20588
# [68]	validation-rmse:5.20611
# [69]	validation-rmse:5.20614
# [70]	validation-rmse:5.20618
# [71]	validation-rmse:5.20572
# [72]	validation-rmse:5.20556
# [73]	validation-rmse:5.20569
# [74]	validation-rmse:5.20553
# [75]	validation-rmse:5.20594
# [76]	validation-rmse:5.20576
# [77]	validation-rmse:5.20609
# [78]	validation-rmse:5.20618
# [79]	validation-rmse:5.20585
# [80]	validation-rmse:5.20573
# [81]	validation-rmse:5.20570
# [82]	validation-rmse:5.20445
# [83]	validation-rmse:5.20453
# [84]	validation-rmse:5.20432
# [85]	validation-rmse:5.20380
# [86]	validation-rmse:5.20414
# [87]	validation-rmse:5.20410
# [88]	validation-rmse:5.20403
# [89]	validation-rmse:5.20415
# [90]	validation-rmse:5.20471
# [91]	validation-rmse:5.20461
# [92]	validation-rmse:5.20466
# [93]	validation-rmse:5.20473
# [94]	validation-rmse:5.20472
#  90%|█████████ | 9/10 [04:04<00:25, 25.30s/trial, best loss: 5.173379212065781]
# 2024/09/26 20:50:40 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:50:40] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/26 20:50:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run fun-colt-385 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/e152c428a8af4fb2925079e3f785c78d.
#
# 2024/09/26 20:50:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# 100%|██████████| 10/10 [04:21<00:00, 26.20s/trial, best loss: 5.173379212065781]
# 2024/09/26 20:50:49 INFO mlflow.tracking._tracking_service.client: 🏃 View run Xgboost Hyper-parameter Optimization at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/178729a31731415987e07d76597b69ed.
# 2024/09/26 20:50:49 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:5.81746
# [1]	validation-rmse:5.42439
# [2]	validation-rmse:5.34844
# [3]	validation-rmse:5.33132
# [4]	validation-rmse:5.32424
# [5]	validation-rmse:5.32280
# [6]	validation-rmse:5.31918
# [7]	validation-rmse:5.31191
# [8]	validation-rmse:5.30447
# [9]	validation-rmse:5.29904
# [10]	validation-rmse:5.29380
# [11]	validation-rmse:5.28780
# [12]	validation-rmse:5.28200
# [13]	validation-rmse:5.28013
# [14]	validation-rmse:5.25849
# [15]	validation-rmse:5.24773
# [16]	validation-rmse:5.24609
# [17]	validation-rmse:5.24593
# [18]	validation-rmse:5.24254
# [19]	validation-rmse:5.23661
# [20]	validation-rmse:5.23600
# [21]	validation-rmse:5.23498
# [22]	validation-rmse:5.23241
# [23]	validation-rmse:5.22884
# [24]	validation-rmse:5.22870
# [25]	validation-rmse:5.22888
# [26]	validation-rmse:5.23149
# [27]	validation-rmse:5.22729
# [28]	validation-rmse:5.22004
# [29]	validation-rmse:5.21835
# [30]	validation-rmse:5.21688
# [31]	validation-rmse:5.20947
# [32]	validation-rmse:5.21035
# [33]	validation-rmse:5.19436
# [34]	validation-rmse:5.19249
# [35]	validation-rmse:5.19230
# [36]	validation-rmse:5.19007
# [37]	validation-rmse:5.19051
# [38]	validation-rmse:5.18953
# [39]	validation-rmse:5.18984
# [40]	validation-rmse:5.18895
# [41]	validation-rmse:5.18998
# [42]	validation-rmse:5.18742
# [43]	validation-rmse:5.18730
# [44]	validation-rmse:5.18795
# [45]	validation-rmse:5.18731
# [46]	validation-rmse:5.18296
# [47]	validation-rmse:5.18275
# [48]	validation-rmse:5.18226
# [49]	validation-rmse:5.18220
# [50]	validation-rmse:5.18212
# [51]	validation-rmse:5.17883
# [52]	validation-rmse:5.17879
# [53]	validation-rmse:5.17886
# [54]	validation-rmse:5.17791
# [55]	validation-rmse:5.17762
# [56]	validation-rmse:5.17695
# [57]	validation-rmse:5.17812
# [58]	validation-rmse:5.17889
# [59]	validation-rmse:5.17810
# [60]	validation-rmse:5.17895
# [61]	validation-rmse:5.17851
# [62]	validation-rmse:5.17784
# [63]	validation-rmse:5.17536
# [64]	validation-rmse:5.17588
# [65]	validation-rmse:5.17618
# [66]	validation-rmse:5.17553
# [67]	validation-rmse:5.17719
# [68]	validation-rmse:5.17719
# [69]	validation-rmse:5.17705
# [70]	validation-rmse:5.17190
# [71]	validation-rmse:5.17341
# [72]	validation-rmse:5.17381
# [73]	validation-rmse:5.17326
# [74]	validation-rmse:5.17188
# [75]	validation-rmse:5.17156
# [76]	validation-rmse:5.17121
# [77]	validation-rmse:5.17118
# [78]	validation-rmse:5.17198
# [79]	validation-rmse:5.17113
# [80]	validation-rmse:5.17195
# [81]	validation-rmse:5.17199
# [82]	validation-rmse:5.17251
# [83]	validation-rmse:5.17219
# [84]	validation-rmse:5.16933
# [85]	validation-rmse:5.16970
# [86]	validation-rmse:5.16980
# [87]	validation-rmse:5.16989
# [88]	validation-rmse:5.16937
# [89]	validation-rmse:5.16954
# [90]	validation-rmse:5.16991
# [91]	validation-rmse:5.17197
# [92]	validation-rmse:5.17283
# [93]	validation-rmse:5.17289
# [94]	validation-rmse:5.17338
# 2024/09/26 20:51:00 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:51:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2024/09/26 20:51:08 INFO mlflow.tracking._tracking_service.client: 🏃 View run Best model ever at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/a931704b702542e2bbcbfdea6b88499b.
# 2024/09/26 20:51:08 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.

# %% [markdown]
# Pero falta todavía registrar dicho modelo en el `model registry`.

# %%
mlflow.set_tracking_uri("https://dagshub.com/luislopez3105/DagsTry.mlflow")
run_id = "a931704b702542e2bbcbfdea6b88499b"  
model_uri = f"runs:/{run_id}/model"
model_name = "Best model ever" 
try:
    mlflow.register_model(model_uri=model_uri, name=model_name)
    print(f"Model '{model_name}' registered successfully.")
except mlflow.exceptions.RestException as e:
    print(f"Error registering model: {e}")
# Out:
# Registered model 'Best model ever' already exists. Creating a new version of this model...
# 2024/09/26 20:54:15 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: Best model ever, version 1
# Model 'Best model ever' registered successfully.
# Created version '1' of model 'Best model ever'.

# %%
from mlflow import MlflowClient
client = MlflowClient()
model_name = "Best model ever"
model_version = '1'  
client.set_registered_model_alias(model_name, "Champion", model_version)
