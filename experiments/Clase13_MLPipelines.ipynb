# %% [markdown]
# # 0. Introducción a Cron y Logger en Python
#
# ## 0.1. ¿Qué es **Cron**?
#
# https://en.wikipedia.org/wiki/Cron
#
# La utilidad de línea de comandos **cron** es un **programador de tareas** (job scheduler) en sistemas operativos basados en `Unix`. Su función es permitir a los usuarios, quienes mantienen y configuran entornos de software, programar trabajos (jobs), como comandos o scripts de shell, conocidos también como **cron jobs**, para ejecutarse periódicamente en tiempos, fechas o intervalos fijos.
#
# Cron se utiliza típicamente para automatizar tareas de mantenimiento o administración del sistema. Sin embargo, su naturaleza general lo hace útil para otras actividades, como descargar archivos desde Internet o revisar correos electrónicos a intervalos regulares.
#
# **Cron** es más adecuado para tareas repetitivas.
#
# El nombre de **cron** proviene de "Chronos", la palabra griega para tiempo.
#
# ```bash
# # * * * * * <command to execute>
# # | | | | |
# # | | | | day of the week (0–6) (Sunday to Saturday; 7 is also Sunday on some systems)
# # | | | month (1–12)
# # | | day of the month (1–31)
# # | hour (0–23)
# # minute (0–59)
# ```
#
# ### Vamos a jugar
# https://crontab.guru/

# %% [markdown]
# ## 0.2. ¿Qué es **Logger** en Python?
#
# A medida que nuestros scripts se vuelven más complejos, necesitamos una forma de **monitorear** lo que está sucediendo en ellos, especialmente cuando algo sale mal. Aquí es donde entra **logging**.
#
# `Python` tiene un módulo integrado llamado `logging` que permite registrar eventos o mensajes en diferentes niveles:
#
# - **DEBUG**: Información detallada, usualmente para desarrolladores.
# - **INFO**: Confirmación de que las cosas están funcionando como se esperaba.
# - **WARNING**: Algo inesperado, pero no crítico.
# - **ERROR**: Fallos debido a un problema en el programa.
# - **CRITICAL**: Error grave, usualmente detiene el programa.
#
# Para usar **logger** en un script de Python:

# %%
import logging

# Configuración básica de logging
logging.basicConfig(
    level=logging.INFO, 
    format='%(asctime)s - %(levelname)s - %(message)s',
)

# Ejemplo de cómo registrar eventos
logging.debug("Este es un mensaje de depuración")
logging.info("Este es un mensaje informativo")
logging.warning("Este es una advertencia")
logging.error("Este es un mensaje de error")
logging.critical("Este es un error crítico")
# Out:
# 21:41:01.761 | WARNING | root - Este es una advertencia
# 21:41:01.764 | ERROR   | root - Este es un mensaje de error
# 21:41:01.766 | CRITICAL | root - Este es un error crítico

# %% [markdown]
# ### Configuración de **Logger** en Python
#
# El módulo `logging` de Python permite una gran flexibilidad para definir cómo y dónde se registran los mensajes. Algunas de las configuraciones más comunes son:
#
# #### 1. **Nivel de Log** (`level`)
# El nivel del log define la gravedad de los mensajes que se quieren capturar. Algunos niveles de log comunes incluyen:
# - `DEBUG`: Información detallada, útil para depuración.
# - `INFO`: Confirmaciones de que el programa está funcionando como se espera.
# - `WARNING`: Indica que algo inesperado sucedió, pero el programa sigue funcionando.
# - `ERROR`: Señala errores más graves, pero que no detienen la ejecución.
# - `CRITICAL`: Errores graves que probablemente detendrán el programa.
#
# Cuando configuramos un **nivel de log**, sólo se capturan los mensajes de ese nivel o superiores. Por ejemplo, si establecemos el nivel en `WARNING`, se registrarán los mensajes `WARNING`, `ERROR` y `CRITICAL`, pero no los `DEBUG` o `INFO`.
#
# #### 2. **Formato del mensaje** (`format`)
# El formato del mensaje permite personalizar cómo se muestran los logs. Algunos componentes útiles en el formato son:
# - `%(asctime)s`: La fecha y hora en que se registró el mensaje.
# - `%(levelname)s`: El nivel del log (DEBUG, INFO, WARNING, etc.).
# - `%(message)s`: El mensaje que se ha registrado.
# - `%(name)s`: El nombre del logger.
# - `%(threadName)s`: El nombre del hilo desde donde se emitió el log.
# - `%(processName)s`: El nombre del proceso que emitió el log.
#
# #### 3. **Formato de fecha y hora** (`datefmt`)
# El parámetro `datefmt` permite personalizar el formato de la fecha y hora que se incluye en los mensajes de log. Puedes usar cualquier formato de fecha y hora compatible con Python, como el que se usa en `strftime`. Esto es útil para ajustar el formato a las necesidades específicas de tu aplicación.
#
# ##### Códigos de Formato Comunes
#
# Aquí tienes algunos códigos de formato comúnmente utilizados que puedes usar con `strftime`:
#
# | Código | Significado                           | Ejemplo de Salida       |
# |--------|---------------------------------------|--------------------------|
# | `%Y`   | Año con siglo                         | `2024`                   |
# | `%y`   | Año sin siglo (00-99)                | `24`                     |
# | `%m`   | Mes como un decimal con ceros (01-12)| `09`                     |
# | `%B`   | Nombre completo del mes               | `Septiembre`             |
# | `%b`   | Nombre abreviado del mes              | `Sep`                    |
# | `%d`   | Día del mes (01-31)                  | `24`                     |
# | `%H`   | Hora (00-23)                         | `14`                     |
# | `%I`   | Hora (01-12)                         | `02`                     |
# | `%M`   | Minuto (00-59)                       | `05`                     |
# | `%S`   | Segundo (00-59)                      | `30`                     |
# | `%p`   | AM o PM                              | `PM`                     |
# | `%A`   | Nombre completo del día de la semana | `Martes`                 |
# | `%a`   | Nombre abreviado del día de la semana | `Mar`                    |
# | `%j`   | Día del año (001-366)                | `267`                    |
# | `%U`   | Número de semana del año (00-53)     | `39`                     |
# | `%W`   | Número de semana del año (00-53), basado en lunes | `39`          |

# %%
import logging
import os

logger = logging.getLogger(__name__)
                           
logging.basicConfig(
    filename='backup.log', 
    level=logging.INFO, 
    format='%(asctime)s - %(levelname)s - %(name)s - %(message)s',
     datefmt='%Y-%m-%d %H:%M:%S',
)

def hacer_respaldo():
    try:
        # Supongamos que aquí ocurre el proceso de respaldo
        logger.info("Respaldo iniciado")
        # Simulación de respaldo
        if os.path.exists('base_de_datos.db'):
            logger.info("Respaldo exitoso")
        else:
            logger.error("Error: La base de datos no existe")
    except Exception as e:
        logger.critical(f"Error crítico durante el respaldo: {e}")

# Ejecutamos la función
hacer_respaldo()
# Out:
# 21:41:01.778 | ERROR   | __main__ - Error: La base de datos no existe

# %% [markdown]
# Ahora sí, empecemos la clase de hoy
#
# # 1. Machine Learning Pipeline a.k.a Workflow Orchestration
#
# > Un pipeline de machine learning es una serie de pasos secuenciales y automatizados que se siguen para entrenar, evaluar y desplegar un modelo de machine learning.
# > El objetivo principal de un pipeline es automatizar el proceso repetitivo de transformar datos crudos en un modelo que pueda usarse en producción.
#
#
# ### Yo tratando de explicar el orden de ejecución de las celdas de mi `jupyter-notebook`:
#
#  <img style="display: block; margin: auto;" src="./images/orchestration-meme.png" width="580" height="50">

# %% [markdown]
# Revisemos lo que hemos hecho hasta ahora con nuestro código...
# 1. Downloading data ----> Ingestion
# 2. Transforming the data ----> Filtering, removing outliers
# 3. Preparing data for ML ----> Feature Engineering
# 4. Hyper-parameter tunning ----> Best params
# 5. Train the final model ----> Best params
# 6. Registry the final model
#
# **Problemas:**
# - Un cuaderno gigante
# - Sin muchas instrucciones
# - Poco legible para cualquier persona
# - No escalable ni mantenible
# - Podríamos decir que es un `workflow`, ya que se debe ejecutar en un orden específico

# %%
def download_data(year, month):
    ...
    return df

def prepare_data(df):
    ...
    return df

def feature_engineering(df):
    ...
    return X, y

def find_best_model(X, y):
    ...
    return params

def train_model(X, y, params):
    ...
    return model

def main():
    df = download_data(2024,1)
    df = prepare_data(df)
    X, y = feature_engineering(df)
    model_params = find_best_model(X, y)
    model = train_model(X, y, model_params)

# %% [markdown]
# Mucho mejor, no?
#
# Pero sigue teniendo problemas:
# - Lo podemos agendar?
# - Qué pasa si tengo múltiples archivos?
# - O si no lo quiero ejecutar en mi máquina local?
# - Qué pasa si una de las funciones falla? Si es solamente temporal el fallo?
# - Y si queremos notificar que ese error ocurrió a algún administrador?
#
# Hay múltiples herramientas que vienen a solventar esos problemas:
#
# - [Apache Airflow](https://airflow.apache.org/)
# - [Prefect](https://www.prefect.io/)
# - [Mage](https://www.mage.ai/)
# - [Dagster](https://dagster.io/)
# - [Kubeflow Pipelines](https://www.kubeflow.org/docs/components/pipelines/)
# - [Scikitlearn Pipelines](https://scikit-learn.org/stable/modules/compose.html#pipeline)

# %% [markdown]
# # 2. Prefect
#
# ## 2.1. Definiciones en **Prefect**
#
# ### 2.1.1. **Task (Tarea)**
# https://docs.prefect.io/3.0/develop/write-tasks
#
# En **Prefect**, una `task` es la unidad más básica de trabajo en un flujo de Prefect. Una `task` representa una operación individual que se ejecuta dentro de un flujo de trabajo (`flow`). Puedes convertir cualquier función de Python en una `task` agregando el decorador `@task`.
#
# Las tasks pueden:
# - **Tomar entradas, realizar un trabajo y devolver salidas**: Realizan operaciones con los datos que reciben y devuelven resultados.
# - **Cachear su ejecución a través de múltiples invocaciones**: Evitar repetir cálculos si una task ya se ejecutó anteriormente con los mismos inputs.
# - **Encapsular la lógica del flujo en unidades reutilizables**: Pueden ser utilizadas en diferentes flows.
# - **Usar logging automático** para capturar detalles de ejecución, etiquetas (tags) y estado final.
# - **Ejecutarse de forma concurrente**: Permiten paralelismo en la ejecución de tareas.
# - **Definirse en el mismo archivo que el `flow` o importarse de módulos**.
# - **Llamarse desde `flows` u otras `tasks`**.
#
# **Ejemplo de una tarea:**
#
# ```python
# from prefect import task
#
# @task
# def sumar(a, b):
#     return a + b
# ```

# %% [markdown]
# ### 2.1.2. **Flow (Flujo)**
# https://docs.prefect.io/3.0/develop/write-flows
#
# Un `flow` en **Prefect** es una colección de `tasks` que se ejecutan de manera organizada y coordinada.
#
# Un `flow` define cómo las `tasks` interactúan entre sí y permite orquestar la ejecución de múltiples `tasks` con reglas específicas, como dependencias, condicionales y paralelismo.
#
# Además, un `flow` puede manejar `tasks` de manera secuencial o en paralelo, así como gestionarlas en función de eventos externos.
#
# Los flows se definen como funciones en Python, y pueden tomar entradas, realizar tareas y devolver resultados. Cualquier función Python puede convertirse en un flow de Prefect añadiendo el decorador `@flow`:
# ```python
# from prefect import flow
#
# @flow
# def mi_flujo_principal():
#     resultado = sumar(3, 4)
#     print(f"El resultado es {resultado}")
# ```
# #### Capacidades de los Flows en Prefect:
#
# Cuando una función se convierte en un `flow`, adquiere las siguientes capacidades:
#
# - **Seguimiento automático de metadatos** sobre las ejecuciones del flujo, como el tiempo de ejecución y el estado final.
# - **Registro de cada estado** que el flujo alcanza, lo que permite observar y actuar sobre cada transición en la ejecución del flow.
# - **Validación de tipos de los argumentos** de entrada como parámetros del flujo de trabajo.
# - **Reintentos automáticos** en caso de fallo, con límites y retrasos configurables.
# - **Timeouts** para evitar que los flujos de trabajo se ejecuten durante demasiado tiempo sin control.
# - **Capacidad de despliegue**, lo que expone una API para interactuar con el flow de manera remota.
#
# Los `flows` se identifican de forma única por su nombre. Puedes especificar un nombre para el `flow` utilizando el parámetro `name`:
#
# ```python
# @flow(name="Mi Flujo")
# def mi_flujo() -> str:
#     return "¡Hola, mundo!"
# ```
#
# Si no proporcionas un nombre, Prefect usará el nombre de la función del flow.
#
# #### Ejecución de `Flows`:
#
# Una ejecución de flow (**flow run**) es una ejecución individual de un `flow`.
#
# Puedes ejecutar un `flow` llamándolo por su nombre de función, de la misma manera que lo harías con una función normal de `Python`. También puedes ejecutar un `flow` mediante:
#
# - **Programadores externos**, como `cron`, para invocar la función del `flow`.
# - **Desplegar el flow en Prefect Cloud** o en un servidor auto-hospedado de Prefect.
# - **Iniciar una ejecución de flow a través de un cronograma**, la interfaz de usuario de Prefect, o la API de Prefect.
#
# Sin importar cómo ejecutes el `flow`, `Prefect` monitorea su ejecución, capturando el estado para observabilidad. Además, puedes registrar una variedad de metadatos sobre las ejecuciones del flow para monitoreo, resolución de problemas y auditoría.

# %% [markdown]
# ### 2.1.3. Diferencias entre `Task` y `Flow`:
#
# - **Task**: Una tarea individual, pequeña y específica que ejecuta una operación.
# - **Flow**: Un contenedor que organiza y coordina la ejecución de varias tasks, permitiendo su orquestación.
#
# ### 2.1.4. Ejemplo Completo de Task y Flow en Prefect:
#
# ```python
# from prefect import task, flow
#
# @task
# def sumar(a, b):
#     return a + b
#
# @flow
# def mi_flujo_principal():
#     resultado = sumar(3, 4)
#     print(f"El resultado es {resultado}")
#
# # Ejecutar el flow
# mi_flujo_principal()
# ```

# %% [markdown]
# ## 2.2 Uso de `Prefect`
#
# ```bash
# pip install prefect
# prefect version
# ```
#
# Ahora vamos a inicializar un servidor de `prefect`
#
# ```bash
# prefect server start
# ```
#
# Vamos a ver un `flow` sencillo

# %%
import httpx
from prefect import flow, task


@task(retries=4, retry_delay_seconds=1, log_prints=True)
def fetch_cat_fact():
    cat_fact = httpx.get("https://f3-vyx5c2hfpq-ue.a.run.app/")
    #An endpoint that is designed to fail sporadically
    if cat_fact.status_code >= 400:
        raise Exception()
    print(cat_fact.text)


@flow
def fetch():
    fetch_cat_fact()

# %%
fetch()
# Out:
# 21:41:02.263 | INFO    | prefect.engine - Created flow run 'gregarious-fossa' for flow 'fetch'
# 21:41:02.684 | INFO    | Task run 'fetch_cat_fact-109' - Created task run 'fetch_cat_fact-109' for task 'fetch_cat_fact'
# 21:41:05.113 | INFO    | Task run 'fetch_cat_fact-109' - Cats do not think that they are little people. They think that we are big cats. This influences their behavior in many ways.
# 21:41:05.122 | INFO    | Task run 'fetch_cat_fact-109' - Finished in state Completed()
# 21:41:05.179 | INFO    | Flow run 'gregarious-fossa' - Finished in state Completed()

# %% [markdown]
# Ahora veamos el concepto de `subflows`

# %%
from prefect import flow


@flow(name="Cat fact")
def fetch_cat_fact():
    """A flow that gets a cat fact"""
    return httpx.get("https://catfact.ninja/fact?max_length=140").json()["fact"]


@flow(name="Dog fact")
def fetch_dog_fact():
    """A flow that gets a dog fact"""
    return httpx.get(
        "https://dogapi.dog/api/v2/facts",
        headers={"accept": "application/json"},
    ).json()["data"][0]["attributes"]["body"]


@flow(name="Animals fact", log_prints=True)
def animal_facts():
    cat_fact = fetch_cat_fact()
    dog_fact = fetch_dog_fact()
    print(f"🐱: {cat_fact} \n🐶: {dog_fact}")

# %%
animal_facts()
# Out:
# 21:41:05.575 | INFO    | prefect.engine - Created flow run 'xanthic-dogfish' for flow 'Animals fact'
# 21:41:06.024 | ERROR   | Flow run 'xanthic-dogfish' - Encountered exception during execution: ModuleNotFoundError("No module named 'httpcore.backends.asyncio'")
# Traceback (most recent call last):
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py", line 652, in run_context
#     yield self
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py", line 696, in run_flow_sync
#     engine.call_flow_fn()
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py", line 675, in call_flow_fn
#     result = call_with_parameters(self.flow.fn, self.parameters)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\utilities\callables.py", line 206, in call_with_parameters
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\luisl\AppData\Local\Temp\ipykernel_4512\2288271524.py", line 21, in animal_facts
#     cat_fact = fetch_cat_fact()
#                ^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flows.py", line 1336, in __call__
#     return run_flow(
#            ^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py", line 818, in run_flow
#     return run_flow_sync(**kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py", line 693, in run_flow_sync
#     with engine.start():
#   File "C:\Python312\Lib\contextlib.py", line 137, in __enter__
#     return next(self.gen)
#            ^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py", line 632, in start
#     with self.initialize_run():
#   File "C:\Python312\Lib\contextlib.py", line 137, in __enter__
#     return next(self.gen)
#            ^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py", line 556, in initialize_run
#     self.flow_run = self.create_flow_run(self.client)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py", line 398, in create_flow_run
#     parent_task_run = run_coro_as_sync(
#                       ^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\utilities\asyncutils.py", line 243, in run_coro_as_sync
#     return call.result()
#            ^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\_internal\concurrency\calls.py", line 312, in result
#     return self.future.result(timeout=timeout)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\_internal\concurrency\calls.py", line 182, in result
#     return self.__get_result()
#            ^^^^^^^^^^^^^^^^^^^
#   File "C:\Python312\Lib\concurrent\futures\_base.py", line 401, in __get_result
#     raise self._exception
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\_internal\concurrency\calls.py", line 383, in _run_async
#     result = await coro
#              ^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\utilities\asyncutils.py", line 225, in coroutine_wrapper
#     return await task
#            ^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\tasks.py", line 818, in create_run
#     task_run = await task_run
#                ^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\orchestration.py", line 2253, in create_task_run
#     response = await self._client.post("/task_runs/", content=content)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py", line 1848, in post
#     cookies=cookies,
#        ^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py", line 1533, in request
#     url: URL | str,
#            ^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\base.py", line 330, in send
#     response = await self._send_with_retry(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\base.py", line 246, in _send_with_retry
#     await self._add_csrf_headers(request=request)
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\base.py", line 379, in _add_csrf_headers
#     token_response = await self.send(token_request)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\base.py", line 330, in send
#     response = await self._send_with_retry(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\base.py", line 254, in _send_with_retry
#     response = await send(request, *send_args, **send_kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py", line 1620, in send
#     files=files,
#            ^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py", line 1648, in _send_handling_auth
#     Send a request.
#
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py", line 1685, in _send_handling_redirects
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py", line 1722, in _send_single_request
#     await auth_flow.aclose()
#                ^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_transports\default.py", line 353, in handle_async_request
#     traceback: TracebackType | None = None,
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\_async\connection_pool.py", line 253, in handle_async_request
#     connection.is_idle()
#     ^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\_async\connection_pool.py", line 237, in handle_async_request
#     Any closing connections are returned, allowing the I/O for closing
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\_async\connection.py", line 86, in handle_async_request
#     self._connection = AsyncHTTP2Connection(
#     ^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\_async\connection.py", line 63, in handle_async_request
#     self._connect_failed: bool = False
#                          ^^^^^^^^^^^^^^
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\_async\connection.py", line 111, in _connect
#     while True:
#
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\backends\auto.py", line 28, in connect_tcp
#   File "c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\backends\auto.py", line 17, in _init_backend
# ModuleNotFoundError: No module named 'httpcore.backends.asyncio'
# 21:41:06.070 | ERROR   | Flow run 'xanthic-dogfish' - Finished in state Failed("Flow run encountered an exception: ModuleNotFoundError: No module named 'httpcore.backends.asyncio'")
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 animal_facts()
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flows.py:1336, in Flow.__call__(self, return_state, wait_for, *args, **kwargs)
#    1332     return track_viz_task(self.isasync, self.name, parameters)
#    1334 from prefect.flow_engine import run_flow
# -> 1336 return run_flow(
#    1337     flow=self,
#    1338     parameters=parameters,
#    1339     wait_for=wait_for,
#    1340     return_type=return_type,
#    1341 )
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:818, in run_flow(flow, flow_run, parameters, wait_for, return_type)
#     816     return run_flow_async(**kwargs)
#     817 else:
# --> 818     return run_flow_sync(**kwargs)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:698, in run_flow_sync(flow, flow_run, parameters, wait_for, return_type)
#     695         with engine.run_context():
#     696             engine.call_flow_fn()
# --> 698 return engine.state if return_type == "state" else engine.result()
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:255, in FlowRunEngine.result(self, raise_on_failure)
#     253 if self._raised is not NotSet:
#     254     if raise_on_failure:
# --> 255         raise self._raised
#     256     return self._raised
#     258 # This is a fall through case which leans on the existing state result mechanics to get the
#     259 # return value. This is necessary because we currently will return a State object if the
#     260 # the State was Prefect-created.
#     261 # TODO: Remove the need to get the result from a State except in cases where the return value
#     262 # is a State object.
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:652, in FlowRunEngine.run_context(self)
#     645     with timeout_context(
#     646         seconds=self.flow.timeout_seconds,
#     647         timeout_exc_type=FlowRunTimeoutError,
#     648     ):
#     649         self.logger.debug(
#     650             f"Executing flow {self.flow.name!r} for flow run {self.flow_run.name!r}..."
#     651         )
# --> 652         yield self
#     653 except TimeoutError as exc:
#     654     self.handle_timeout(exc)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:696, in run_flow_sync(flow, flow_run, parameters, wait_for, return_type)
#     694     while engine.is_running():
#     695         with engine.run_context():
# --> 696             engine.call_flow_fn()
#     698 return engine.state if return_type == "state" else engine.result()
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:675, in FlowRunEngine.call_flow_fn(self)
#     673     return _call_flow_fn()
#     674 else:
# --> 675     result = call_with_parameters(self.flow.fn, self.parameters)
#     676     self.handle_success(result)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\utilities\callables.py:206, in call_with_parameters(fn, parameters)
#     198 """
#     199 Call a function with parameters extracted with `get_call_parameters`
#     200
#    (...)
#     203 the args/kwargs using `parameters_to_positional_and_keyword` directly
#     204 """
#     205 args, kwargs = parameters_to_args_kwargs(fn, parameters)
# --> 206 return fn(*args, **kwargs)
#
# Cell In[19], line 21, in animal_facts()
#      19 @flow(name="Animals fact", log_prints=True)
#      20 def animal_facts():
# ---> 21     cat_fact = fetch_cat_fact()
#      22     dog_fact = fetch_dog_fact()
#      23     print(f"🐱: {cat_fact} \n🐶: {dog_fact}")
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flows.py:1336, in Flow.__call__(self, return_state, wait_for, *args, **kwargs)
#    1332     return track_viz_task(self.isasync, self.name, parameters)
#    1334 from prefect.flow_engine import run_flow
# -> 1336 return run_flow(
#    1337     flow=self,
#    1338     parameters=parameters,
#    1339     wait_for=wait_for,
#    1340     return_type=return_type,
#    1341 )
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:818, in run_flow(flow, flow_run, parameters, wait_for, return_type)
#     816     return run_flow_async(**kwargs)
#     817 else:
# --> 818     return run_flow_sync(**kwargs)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:693, in run_flow_sync(flow, flow_run, parameters, wait_for, return_type)
#     679 def run_flow_sync(
#     680     flow: Flow[P, R],
#     681     flow_run: Optional[FlowRun] = None,
#    (...)
#     684     return_type: Literal["state", "result"] = "result",
#     685 ) -> Union[R, State, None]:
#     686     engine = FlowRunEngine[P, R](
#     687         flow=flow,
#     688         parameters=parameters,
#     689         flow_run=flow_run,
#     690         wait_for=wait_for,
#     691     )
# --> 693     with engine.start():
#     694         while engine.is_running():
#     695             with engine.run_context():
#
# File C:\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:632, in FlowRunEngine.start(self)
#     630 @contextmanager
#     631 def start(self) -> Generator[None, None, None]:
# --> 632     with self.initialize_run():
#     633         self.begin_run()
#     635         if self.state.is_running():
#
# File C:\Python312\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:556, in FlowRunEngine.initialize_run(self)
#     553 self._is_started = True
#     555 if not self.flow_run:
# --> 556     self.flow_run = self.create_flow_run(self.client)
#     557     flow_run_url = url_for(self.flow_run)
#     559     if flow_run_url:
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\flow_engine.py:398, in FlowRunEngine.create_flow_run(self, client)
#     392 if flow_run_ctx:
#     393     # add a task to a parent flow run that represents the execution of a subflow run
#     394     parent_task = Task(
#     395         name=self.flow.name, fn=self.flow.fn, version=self.flow.version
#     396     )
# --> 398     parent_task_run = run_coro_as_sync(
#     399         parent_task.create_run(
#     400             flow_run_context=flow_run_ctx,
#     401             parameters=self.parameters,
#     402             wait_for=self.wait_for,
#     403         )
#     404     )
#     406     # check if there is already a flow run for this subflow
#     407     if subflow_run := self.load_subflow_run(
#     408         parent_task_run=parent_task_run, client=client, context=flow_run_ctx
#     409     ):
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\utilities\asyncutils.py:243, in run_coro_as_sync(coroutine, force_new_thread, wait_for_result)
#     241 runner.submit(call)
#     242 try:
# --> 243     return call.result()
#     244 except KeyboardInterrupt:
#     245     call.cancel()
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\_internal\concurrency\calls.py:312, in Call.result(self, timeout)
#     306 def result(self, timeout: Optional[float] = None) -> T:
#     307     """
#     308     Wait for the result of the call.
#     309
#     310     Not safe for use from asynchronous contexts.
#     311     """
# --> 312     return self.future.result(timeout=timeout)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\_internal\concurrency\calls.py:182, in Future.result(self, timeout)
#     180     raise CancelledError()
#     181 elif self._state == FINISHED:
# --> 182     return self.__get_result()
#     183 else:
#     184     raise TimeoutError()
#
# File C:\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\_internal\concurrency\calls.py:383, in Call._run_async(***failed resolving arguments***)
#     381 with self.future.enforce_async_deadline() as cancel_scope:
#     382     try:
# --> 383         result = await coro
#     384     finally:
#     385         # Forget this call's arguments in order to free up any memory
#     386         # that may be referenced by them; after a call has happened,
#     387         # there's no need to keep a reference to them
#     388         self.args = None
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\utilities\asyncutils.py:225, in run_coro_as_sync.<locals>.coroutine_wrapper()
#     223     task = create_task(coroutine)
#     224     if wait_for_result:
# --> 225         return await task
#     226 finally:
#     227     RUNNING_IN_RUN_SYNC_LOOP_FLAG.reset(token1)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\tasks.py:818, in Task.create_run(self, client, id, parameters, flow_run_context, parent_task_run_context, wait_for, extra_task_inputs, deferred)
#     816 # the new engine uses sync clients but old engines use async clients
#     817 if inspect.isawaitable(task_run):
# --> 818     task_run = await task_run
#     820 return task_run
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\orchestration.py:2253, in PrefectClient.create_task_run(self, task, flow_run_id, dynamic_key, id, name, extra_tags, state, task_inputs)
#    2235 task_run_data = TaskRunCreate(
#    2236     id=id,
#    2237     name=name,
#    (...)
#    2249     task_inputs=task_inputs or {},
#    2250 )
#    2251 content = task_run_data.model_dump_json(exclude={"id"} if id is None else None)
# -> 2253 response = await self._client.post("/task_runs/", content=content)
#    2254 return TaskRun.model_validate(response.json())
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py:1848, in post(self, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1826 async def options(
#    1827     self,
#    1828     url: URL | str,
#    (...)
#    1836     extensions: RequestExtensions | None = None,
#    1837 ) -> Response:
#    1838     """
#    1839     Send an `OPTIONS` request.
#    1840
#    1841     **Parameters**: See `httpx.request`.
#    1842     """
#    1843     return await self.request(
#    1844         "OPTIONS",
#    1845         url,
#    1846         params=params,
#    1847         headers=headers,
# -> 1848         cookies=cookies,
#    1849         auth=auth,
#    1850         follow_redirects=follow_redirects,
#    1851         timeout=timeout,
#    1852         extensions=extensions,
#    1853     )
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py:1533, in request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1526             return self._transport if transport is None else transport
#    1528     return self._transport
#    1530 async def request(
#    1531     self,
#    1532     method: str,
# -> 1533     url: URL | str,
#    1534     *,
#    1535     content: RequestContent | None = None,
#    1536     data: RequestData | None = None,
#    1537     files: RequestFiles | None = None,
#    1538     json: typing.Any | None = None,
#    1539     params: QueryParamTypes | None = None,
#    1540     headers: HeaderTypes | None = None,
#    1541     cookies: CookieTypes | None = None,
#    1542     auth: AuthTypes | UseClientDefault | None = USE_CLIENT_DEFAULT,
#    1543     follow_redirects: bool | UseClientDefault = USE_CLIENT_DEFAULT,
#    1544     timeout: TimeoutTypes | UseClientDefault = USE_CLIENT_DEFAULT,
#    1545     extensions: RequestExtensions | None = None,
#    1546 ) -> Response:
#    1547     """
#    1548     Build and send a request.
#    1549
#    (...)
#    1561     [0]: /advanced/clients/#merging-of-configuration
#    1562     """
#    1564     if cookies is not None:  # pragma: no cover
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\base.py:330, in PrefectHttpxAsyncClient.send(self, request, *args, **kwargs)
#     318 """
#     319 Send a request with automatic retry behavior for the following status codes:
#     320
#    (...)
#     326 - Any additional status codes provided in `PREFECT_CLIENT_RETRY_EXTRA_CODES`
#     327 """
#     329 super_send = super().send
# --> 330 response = await self._send_with_retry(
#     331     request=request,
#     332     send=super_send,
#     333     send_args=args,
#     334     send_kwargs=kwargs,
#     335     retry_codes={
#     336         status.HTTP_429_TOO_MANY_REQUESTS,
#     337         status.HTTP_503_SERVICE_UNAVAILABLE,
#     338         status.HTTP_502_BAD_GATEWAY,
#     339         status.HTTP_408_REQUEST_TIMEOUT,
#     340         *PREFECT_CLIENT_RETRY_EXTRA_CODES.value(),
#     341     },
#     342     retry_exceptions=(
#     343         httpx.ReadTimeout,
#     344         httpx.PoolTimeout,
#     345         httpx.ConnectTimeout,
#     346         # `ConnectionResetError` when reading socket raises as a `ReadError`
#     347         httpx.ReadError,
#     348         # Sockets can be closed during writes resulting in a `WriteError`
#     349         httpx.WriteError,
#     350         # Uvicorn bug, see https://github.com/PrefectHQ/prefect/issues/7512
#     351         httpx.RemoteProtocolError,
#     352         # HTTP2 bug, see https://github.com/PrefectHQ/prefect/issues/7442
#     353         httpx.LocalProtocolError,
#     354     ),
#     355 )
#     357 # Convert to a Prefect response to add nicer errors messages
#     358 response = PrefectResponse.from_httpx_response(response)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\base.py:246, in PrefectHttpxAsyncClient._send_with_retry(self, request, send, send_args, send_kwargs, retry_codes, retry_exceptions)
#     243 is_change_request = request.method.lower() in {"post", "put", "patch", "delete"}
#     245 if self.enable_csrf_support and is_change_request:
# --> 246     await self._add_csrf_headers(request=request)
#     248 while try_count <= PREFECT_CLIENT_MAX_RETRIES.value():
#     249     try_count += 1
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\base.py:379, in PrefectHttpxAsyncClient._add_csrf_headers(self, request)
#     374 token_request = self.build_request(
#     375     "GET", f"/csrf-token?client={self.csrf_client_id}"
#     376 )
#     378 try:
# --> 379     token_response = await self.send(token_request)
#     380 except PrefectHTTPStatusError as exc:
#     381     old_server = exc.response.status_code == status.HTTP_404_NOT_FOUND
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\base.py:330, in PrefectHttpxAsyncClient.send(self, request, *args, **kwargs)
#     318 """
#     319 Send a request with automatic retry behavior for the following status codes:
#     320
#    (...)
#     326 - Any additional status codes provided in `PREFECT_CLIENT_RETRY_EXTRA_CODES`
#     327 """
#     329 super_send = super().send
# --> 330 response = await self._send_with_retry(
#     331     request=request,
#     332     send=super_send,
#     333     send_args=args,
#     334     send_kwargs=kwargs,
#     335     retry_codes={
#     336         status.HTTP_429_TOO_MANY_REQUESTS,
#     337         status.HTTP_503_SERVICE_UNAVAILABLE,
#     338         status.HTTP_502_BAD_GATEWAY,
#     339         status.HTTP_408_REQUEST_TIMEOUT,
#     340         *PREFECT_CLIENT_RETRY_EXTRA_CODES.value(),
#     341     },
#     342     retry_exceptions=(
#     343         httpx.ReadTimeout,
#     344         httpx.PoolTimeout,
#     345         httpx.ConnectTimeout,
#     346         # `ConnectionResetError` when reading socket raises as a `ReadError`
#     347         httpx.ReadError,
#     348         # Sockets can be closed during writes resulting in a `WriteError`
#     349         httpx.WriteError,
#     350         # Uvicorn bug, see https://github.com/PrefectHQ/prefect/issues/7512
#     351         httpx.RemoteProtocolError,
#     352         # HTTP2 bug, see https://github.com/PrefectHQ/prefect/issues/7442
#     353         httpx.LocalProtocolError,
#     354     ),
#     355 )
#     357 # Convert to a Prefect response to add nicer errors messages
#     358 response = PrefectResponse.from_httpx_response(response)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\prefect\client\base.py:254, in PrefectHttpxAsyncClient._send_with_retry(self, request, send, send_args, send_kwargs, retry_codes, retry_exceptions)
#     251 exc_info = None
#     253 try:
# --> 254     response = await send(request, *send_args, **send_kwargs)
#     255 except retry_exceptions:  # type: ignore
#     256     if try_count > PREFECT_CLIENT_MAX_RETRIES.value():
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py:1620, in send(self, request, stream, auth, follow_redirects)
#    1587 @asynccontextmanager
#    1588 async def stream(
#    1589     self,
#    (...)
#    1603     extensions: RequestExtensions | None = None,
#    1604 ) -> typing.AsyncIterator[Response]:
#    1605     """
#    1606     Alternative to `httpx.request()` that streams the response body
#    1607     instead of loading it into memory at once.
#    (...)
#    1613     [0]: /quickstart#streaming-responses
#    1614     """
#    1615     request = self.build_request(
#    1616         method=method,
#    1617         url=url,
#    1618         content=content,
#    1619         data=data,
# -> 1620         files=files,
#    1621         json=json,
#    1622         params=params,
#    1623         headers=headers,
#    1624         cookies=cookies,
#    1625         timeout=timeout,
#    1626         extensions=extensions,
#    1627     )
#    1628     response = await self.send(
#    1629         request=request,
#    1630         auth=auth,
#    1631         follow_redirects=follow_redirects,
#    1632         stream=True,
#    1633     )
#    1634     try:
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py:1648, in _send_handling_auth(self, request, auth, follow_redirects, history)
#    1639 async def send(
#    1640     self,
#    1641     request: Request,
#    (...)
#    1645     follow_redirects: bool | UseClientDefault = USE_CLIENT_DEFAULT,
#    1646 ) -> Response:
#    1647     """
# -> 1648     Send a request.
#    1649
#    1650     The request is sent as-is, unmodified.
#    1651
#    1652     Typically you'll want to build one with `AsyncClient.build_request()`
#    1653     so that any client-level configuration is merged into the request,
#    1654     but passing an explicit `httpx.Request()` is supported as well.
#    1655
#    1656     See also: [Request instances][0]
#    1657
#    1658     [0]: /advanced/clients/#request-instances
#    1659     """
#    1660     if self._state == ClientState.CLOSED:
#    1661         raise RuntimeError("Cannot send a request, as the client has been closed.")
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py:1685, in _send_handling_redirects(self, request, follow_redirects, history)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_client.py:1722, in _send_single_request(self, request)
#    1720             raise exc
#    1721 finally:
# -> 1722     await auth_flow.aclose()
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpx\_transports\default.py:353, in handle_async_request(self, request)
#     346     await self._pool.__aenter__()
#     347     return self
#     349 async def __aexit__(
#     350     self,
#     351     exc_type: type[BaseException] | None = None,
#     352     exc_value: BaseException | None = None,
# --> 353     traceback: TracebackType | None = None,
#     354 ) -> None:
#     355     with map_httpcore_exceptions():
#     356         await self._pool.__aexit__(exc_type, exc_value, traceback)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\_async\connection_pool.py:253, in handle_async_request(self, request)
#     250     self._connections.remove(connection)
#     251     closing_connections.append(connection)
#     252 elif (
# --> 253     connection.is_idle()
#     254     and len([connection.is_idle() for connection in self._connections])
#     255     > self._max_keepalive_connections
#     256 ):
#     257     # log: "closing idle connection"
#     258     self._connections.remove(connection)
#     259     closing_connections.append(connection)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\_async\connection_pool.py:237, in handle_async_request(self, request)
#     230 def _assign_requests_to_connections(self) -> List[AsyncConnectionInterface]:
#     231     """
#     232     Manage the state of the connection pool, assigning incoming
#     233     requests to connections as available.
#     234
#     235     Called whenever a new request is added or removed from the pool.
#     236
# --> 237     Any closing connections are returned, allowing the I/O for closing
#     238     those connections to be handled seperately.
#     239     """
#     240     closing_connections = []
#     242     # First we handle cleaning up any connections that are closed,
#     243     # have expired their keep-alive, or surplus idle connections.
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\_async\connection.py:86, in handle_async_request(self, request)
#      83 if http2_negotiated or (self._http2 and not self._http1):
#      84     from .http2 import AsyncHTTP2Connection
# ---> 86     self._connection = AsyncHTTP2Connection(
#      87         origin=self._origin,
#      88         stream=stream,
#      89         keepalive_expiry=self._keepalive_expiry,
#      90     )
#      91 else:
#      92     self._connection = AsyncHTTP11Connection(
#      93         origin=self._origin,
#      94         stream=stream,
#      95         keepalive_expiry=self._keepalive_expiry,
#      96     )
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\_async\connection.py:63, in handle_async_request(self, request)
#      59 self._network_backend: AsyncNetworkBackend = (
#      60     AutoBackend() if network_backend is None else network_backend
#      61 )
#      62 self._connection: Optional[AsyncConnectionInterface] = None
# ---> 63 self._connect_failed: bool = False
#      64 self._request_lock = AsyncLock()
#      65 self._socket_options = socket_options
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\_async\connection.py:111, in _connect(self, request)
#     108 retries_left = self._retries
#     109 delays = exponential_backoff(factor=RETRIES_BACKOFF_FACTOR)
# --> 111 while True:
#     112     try:
#     113         if self._uds is None:
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\backends\auto.py:28, in connect_tcp(self, host, port, timeout, local_address)
#
# File c:\proggg\DagsTry\venv\Lib\site-packages\httpcore\backends\auto.py:17, in _init_backend(self)
#
# ModuleNotFoundError: No module named 'httpcore.backends.asyncio'

# %% [markdown]
# Ahora vamos a hacerlo para nuestro pipeline de entrenamiento en nuestro proyecto `nyc-taxi-time-prediction`
#
# - Vamos a crear una nueva rama `feat/training_orchestration`.
# - Vamos a crear un nuevo directorio `training pipeline`
# - crear un archivo llamado `train.py`

# %%
import pickle
import mlflow
import pathlib
import dagshub
import pandas as pd
import xgboost as xgb
from hyperopt.pyll import scope
from sklearn.metrics import root_mean_squared_error
from sklearn.feature_extraction import DictVectorizer
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials


def read_data(file_path: str) -> pd.DataFrame:
    """Read data into DataFrame"""
    df = pd.read_parquet(file_path)

    df.lpep_dropoff_datetime = pd.to_datetime(df.lpep_dropoff_datetime)
    df.lpep_pickup_datetime = pd.to_datetime(df.lpep_pickup_datetime)

    df["duration"] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <= 60)]

    categorical = ["PULocationID", "DOLocationID"]
    df[categorical] = df[categorical].astype(str)

    return df

def add_features(df_train: pd.DataFrame, df_val: pd.DataFrame):
    """Add features to the model"""
    df_train["PU_DO"] = df_train["PULocationID"] + "_" + df_train["DOLocationID"]
    df_val["PU_DO"] = df_val["PULocationID"] + "_" + df_val["DOLocationID"]

    categorical = ["PU_DO"]  #'PULocationID', 'DOLocationID']
    numerical = ["trip_distance"]

    dv = DictVectorizer()

    train_dicts = df_train[categorical + numerical].to_dict(orient="records")
    X_train = dv.fit_transform(train_dicts)

    val_dicts = df_val[categorical + numerical].to_dict(orient="records")
    X_val = dv.transform(val_dicts)

    y_train = df_train["duration"].values
    y_val = df_val["duration"].values
    return X_train, X_val, y_train, y_val, dv

def hyper_parameter_tunning(X_train, X_val, y_train, y_val, dv):
    
    mlflow.xgboost.autolog()
    
    training_dataset = mlflow.data.from_numpy(X_train.data, targets=y_train, name="green_tripdata_2024-01")
    
    validation_dataset = mlflow.data.from_numpy(X_val.data, targets=y_val, name="green_tripdata_2024-02")
    
    train = xgb.DMatrix(X_train, label=y_train)
    
    valid = xgb.DMatrix(X_val, label=y_val)
    
    def objective(params):
        with mlflow.start_run(nested=True):
             
            # Tag model
            mlflow.set_tag("model_family", "xgboost")
            
            # Train model
            booster = xgb.train(
                params=params,
                dtrain=train,
                num_boost_round=100,
                evals=[(valid, 'validation')],
                early_stopping_rounds=10
            )
            
            # Predict in the val dataset
            y_pred = booster.predict(valid)
            
            # Calculate metric
            rmse = root_mean_squared_error(y_val, y_pred)
            
            # Log performance metric
            mlflow.log_metric("rmse", rmse)
    
        return {'loss': rmse, 'status': STATUS_OK}

    with mlflow.start_run(run_name="Xgboost Hyper-parameter Optimization", nested=True):
        search_space = {
            'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
            'learning_rate': hp.loguniform('learning_rate', -3, 0),
            'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
            'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
            'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
            'objective': 'reg:squarederror',
            'seed': 42
        }
        
        best_params = fmin(
            fn=objective,
            space=search_space,
            algo=tpe.suggest,
            max_evals=10,
            trials=Trials()
        )
        best_params["max_depth"] = int(best_params["max_depth"])
        best_params["seed"] = 42
        best_params["objective"] = "reg:squarederror"
        
        mlflow.log_params(best_params)

    return best_params


def train_best_model(X_train, X_val, y_train, y_val, dv, best_params) -> None:
    """train a model with best hyperparams and write everything out"""

    with mlflow.start_run(run_name="Best model ever"):
        train = xgb.DMatrix(X_train, label=y_train)
        valid = xgb.DMatrix(X_val, label=y_val)

        mlflow.log_params(best_params)

        # Log a fit model instance
        booster = xgb.train(
            params=best_params,
            dtrain=train,
            num_boost_round=100,
            evals=[(valid, 'validation')],
            early_stopping_rounds=10
        )

        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)

        pathlib.Path("models").mkdir(exist_ok=True)
        with open("models/preprocessor.b", "wb") as f_out:
            pickle.dump(dv, f_out)
        
        mlflow.log_artifact("models/preprocessor.b", artifact_path="preprocessor")
    
    return None

def main_flow(year: int, month_train: str, month_val: str) -> None:
    """The main training pipeline"""
    
    train_path = f"../data/green_tripdata_{year}-{month_train}.parquet"
    val_path = f"../data/green_tripdata_{year}-{month_val}.parquet"
    
    # MLflow settings
    dagshub.init(url="https://dagshub.com/luislopez3105/DagsTry", mlflow=True)
    
    MLFLOW_TRACKING_URI = mlflow.get_tracking_uri()
    
    mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)
    mlflow.set_experiment(experiment_name="nyc-taxi-experiment-prefect")

    # Load
    df_train = read_data(train_path)
    df_val = read_data(val_path)

    # Transform
    X_train, X_val, y_train, y_val, dv = add_features(df_train, df_val)
    
    # Hyper-parameter Tunning
    best_params = hyper_parameter_tunning(X_train, X_val, y_train, y_val, dv)
    
    # Train
    train_best_model(X_train, X_val, y_train, y_val, dv, best_params)
main_flow(year="2024",month_train='01',month_val='02')
# Out:
# Initialized MLflow to track repo "luislopez3105/DagsTry"
# Repository luislopez3105/DagsTry initialized!
# [0]	validation-rmse:5.91431
# [1]	validation-rmse:5.35772
# [2]	validation-rmse:5.24502
# [3]	validation-rmse:5.21896
# [4]	validation-rmse:5.21355
# [5]	validation-rmse:5.21324
# [6]	validation-rmse:5.21387
# [7]	validation-rmse:5.21293
# [8]	validation-rmse:5.21250
# [9]	validation-rmse:5.21372
# [10]	validation-rmse:5.21379
# [11]	validation-rmse:5.21469
# [12]	validation-rmse:5.21403
# [13]	validation-rmse:5.21354
# [14]	validation-rmse:5.21213
# [15]	validation-rmse:5.21141
# [16]	validation-rmse:5.20700
# [17]	validation-rmse:5.20780
# [18]	validation-rmse:5.20826
# [19]	validation-rmse:5.21000
# [20]	validation-rmse:5.20887
# [21]	validation-rmse:5.20935
# [22]	validation-rmse:5.21047
# [23]	validation-rmse:5.20668
# [24]	validation-rmse:5.20860
# [25]	validation-rmse:5.20869
# [26]	validation-rmse:5.20991
# [27]	validation-rmse:5.20961
# [28]	validation-rmse:5.21211
# [29]	validation-rmse:5.21253
# [30]	validation-rmse:5.21350
# [31]	validation-rmse:5.21352
# [32]	validation-rmse:5.21434
# [33]	validation-rmse:5.22060
#   0%|          | 0/10 [00:09<?, ?trial/s, best loss=?]
# 2024/09/24 21:44:45 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:44:45] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/24 21:44:53 INFO mlflow.tracking._tracking_service.client: 🏃 View run intelligent-koi-154 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/2a77b2a0eca241e79067a2f14daec4eb.
#
# 2024/09/24 21:44:53 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:7.94793
# [1]	validation-rmse:7.10300
# [2]	validation-rmse:6.50208
# [3]	validation-rmse:6.08497
# [4]	validation-rmse:5.80116
# [5]	validation-rmse:5.60959
# [6]	validation-rmse:5.48424
# [7]	validation-rmse:5.40214
# [8]	validation-rmse:5.34792
# [9]	validation-rmse:5.31322
# [10]	validation-rmse:5.29045
# [11]	validation-rmse:5.27502
# [12]	validation-rmse:5.26309
# [13]	validation-rmse:5.25429
# [14]	validation-rmse:5.24716
# [15]	validation-rmse:5.24316
# [16]	validation-rmse:5.23808
# [17]	validation-rmse:5.23575
# [18]	validation-rmse:5.23349
# [19]	validation-rmse:5.23098
# [20]	validation-rmse:5.23004
# [21]	validation-rmse:5.22862
# [22]	validation-rmse:5.22841
# [23]	validation-rmse:5.22542
# [24]	validation-rmse:5.22240
# [25]	validation-rmse:5.22274
# [26]	validation-rmse:5.22287
# [27]	validation-rmse:5.22282
# [28]	validation-rmse:5.22237
# [29]	validation-rmse:5.22229
# [30]	validation-rmse:5.22197
# [31]	validation-rmse:5.22272
# [32]	validation-rmse:5.21946
# [33]	validation-rmse:5.21875
# [34]	validation-rmse:5.21652
# [35]	validation-rmse:5.21654
# [36]	validation-rmse:5.21674
# [37]	validation-rmse:5.21688
# [38]	validation-rmse:5.21760
# [39]	validation-rmse:5.21797
# [40]	validation-rmse:5.21523
# [41]	validation-rmse:5.21484
# [42]	validation-rmse:5.21488
# [43]	validation-rmse:5.21427
# [44]	validation-rmse:5.21446
# [45]	validation-rmse:5.21419
# [46]	validation-rmse:5.21448
# [47]	validation-rmse:5.21394
# [48]	validation-rmse:5.21428
# [49]	validation-rmse:5.21439
# [50]	validation-rmse:5.21441
# [51]	validation-rmse:5.21414
# [52]	validation-rmse:5.21384
# [53]	validation-rmse:5.21408
# [54]	validation-rmse:5.21293
# [55]	validation-rmse:5.21251
# [56]	validation-rmse:5.21235
# [57]	validation-rmse:5.21234
# [58]	validation-rmse:5.21238
# [59]	validation-rmse:5.21159
# [60]	validation-rmse:5.21159
# [61]	validation-rmse:5.21173
# [62]	validation-rmse:5.21155
# [63]	validation-rmse:5.21045
# [64]	validation-rmse:5.21038
# [65]	validation-rmse:5.21014
# [66]	validation-rmse:5.21025
# [67]	validation-rmse:5.21054
# [68]	validation-rmse:5.21012
# [69]	validation-rmse:5.20951
# [70]	validation-rmse:5.20898
# [71]	validation-rmse:5.20695
# [72]	validation-rmse:5.20627
# [73]	validation-rmse:5.20674
# [74]	validation-rmse:5.20650
# [75]	validation-rmse:5.20617
# [76]	validation-rmse:5.20617
# [77]	validation-rmse:5.20628
# [78]	validation-rmse:5.20605
# [79]	validation-rmse:5.20596
# [80]	validation-rmse:5.20620
# [81]	validation-rmse:5.20663
# [82]	validation-rmse:5.20651
# [83]	validation-rmse:5.20644
# [84]	validation-rmse:5.20624
# [85]	validation-rmse:5.20626
# [86]	validation-rmse:5.20654
# [87]	validation-rmse:5.20637
# [88]	validation-rmse:5.20654
#  10%|█         | 1/10 [00:45<04:02, 26.94s/trial, best loss: 5.220595924134868]
# 2024/09/24 21:45:19 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:45:19] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/24 21:45:27 INFO mlflow.tracking._tracking_service.client: 🏃 View run whimsical-ox-159 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/995d680f0ffe4a0e8436fb1295600ba8.
#
# 2024/09/24 21:45:27 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:8.58477
# [1]	validation-rmse:8.12109
# [2]	validation-rmse:7.72100
# [3]	validation-rmse:7.36576
# [4]	validation-rmse:7.06980
# [5]	validation-rmse:6.80787
# [6]	validation-rmse:6.58620
# [7]	validation-rmse:6.39253
# [8]	validation-rmse:6.23967
# [9]	validation-rmse:6.08925
# [10]	validation-rmse:5.97627
# [11]	validation-rmse:5.87670
# [12]	validation-rmse:5.79516
# [13]	validation-rmse:5.72398
# [14]	validation-rmse:5.66169
# [15]	validation-rmse:5.60782
# [16]	validation-rmse:5.57183
# [17]	validation-rmse:5.53786
# [18]	validation-rmse:5.50270
# [19]	validation-rmse:5.48084
# [20]	validation-rmse:5.45608
# [21]	validation-rmse:5.43928
# [22]	validation-rmse:5.42754
# [23]	validation-rmse:5.40921
# [24]	validation-rmse:5.40157
# [25]	validation-rmse:5.39494
# [26]	validation-rmse:5.38463
# [27]	validation-rmse:5.38105
# [28]	validation-rmse:5.37764
# [29]	validation-rmse:5.36900
# [30]	validation-rmse:5.36574
# [31]	validation-rmse:5.36315
# [32]	validation-rmse:5.35720
# [33]	validation-rmse:5.35446
# [34]	validation-rmse:5.35492
# [35]	validation-rmse:5.35036
# [36]	validation-rmse:5.34951
# [37]	validation-rmse:5.34866
# [38]	validation-rmse:5.34909
# [39]	validation-rmse:5.34796
# [40]	validation-rmse:5.34659
# [41]	validation-rmse:5.34552
# [42]	validation-rmse:5.34394
# [43]	validation-rmse:5.34336
# [44]	validation-rmse:5.34232
# [45]	validation-rmse:5.34159
# [46]	validation-rmse:5.34032
# [47]	validation-rmse:5.33932
# [48]	validation-rmse:5.33842
# [49]	validation-rmse:5.33772
# [50]	validation-rmse:5.33763
# [51]	validation-rmse:5.33675
# [52]	validation-rmse:5.33660
# [53]	validation-rmse:5.33532
# [54]	validation-rmse:5.33460
# [55]	validation-rmse:5.33460
# [56]	validation-rmse:5.33376
# [57]	validation-rmse:5.33328
# [58]	validation-rmse:5.33314
# [59]	validation-rmse:5.33369
# [60]	validation-rmse:5.33225
# [61]	validation-rmse:5.33208
# [62]	validation-rmse:5.33229
# [63]	validation-rmse:5.33148
# [64]	validation-rmse:5.33075
# [65]	validation-rmse:5.33066
# [66]	validation-rmse:5.32953
# [67]	validation-rmse:5.32962
# [68]	validation-rmse:5.32880
# [69]	validation-rmse:5.32929
# [70]	validation-rmse:5.32869
# [71]	validation-rmse:5.32888
# [72]	validation-rmse:5.32900
# [73]	validation-rmse:5.32801
# [74]	validation-rmse:5.32804
# [75]	validation-rmse:5.32670
# [76]	validation-rmse:5.32646
# [77]	validation-rmse:5.32705
# [78]	validation-rmse:5.32663
# [79]	validation-rmse:5.32666
# [80]	validation-rmse:5.32639
# [81]	validation-rmse:5.32669
# [82]	validation-rmse:5.32621
# [83]	validation-rmse:5.32636
# [84]	validation-rmse:5.32642
# [85]	validation-rmse:5.32559
# [86]	validation-rmse:5.32557
# [87]	validation-rmse:5.32601
# [88]	validation-rmse:5.32470
# [89]	validation-rmse:5.32435
# [90]	validation-rmse:5.32463
# [91]	validation-rmse:5.32501
# [92]	validation-rmse:5.32472
# [93]	validation-rmse:5.32443
# [94]	validation-rmse:5.32475
# [95]	validation-rmse:5.32454
# [96]	validation-rmse:5.32458
# [97]	validation-rmse:5.32386
# [98]	validation-rmse:5.32390
# [99]	validation-rmse:5.32359
#  20%|██        | 2/10 [01:36<04:09, 31.20s/trial, best loss: 5.2063899533766484]
# 2024/09/24 21:46:28 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:46:28] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/24 21:46:38 INFO mlflow.tracking._tracking_service.client: 🏃 View run legendary-stag-490 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/dfcafe22f2724a878ab5a740aa568b08.
#
# 2024/09/24 21:46:38 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:7.43432
# [1]	validation-rmse:6.47960
# [2]	validation-rmse:5.92434
# [3]	validation-rmse:5.64103
# [4]	validation-rmse:5.49542
# [5]	validation-rmse:5.41114
# [6]	validation-rmse:5.34852
# [7]	validation-rmse:5.32811
# [8]	validation-rmse:5.31503
# [9]	validation-rmse:5.31052
# [10]	validation-rmse:5.30358
# [11]	validation-rmse:5.29892
# [12]	validation-rmse:5.29563
# [13]	validation-rmse:5.28785
# [14]	validation-rmse:5.28634
# [15]	validation-rmse:5.28558
# [16]	validation-rmse:5.28197
# [17]	validation-rmse:5.28068
# [18]	validation-rmse:5.27623
# [19]	validation-rmse:5.27669
# [20]	validation-rmse:5.27448
# [21]	validation-rmse:5.27410
# [22]	validation-rmse:5.27201
# [23]	validation-rmse:5.27154
# [24]	validation-rmse:5.27225
# [25]	validation-rmse:5.26977
# [26]	validation-rmse:5.26882
# [27]	validation-rmse:5.26907
# [28]	validation-rmse:5.26904
# [29]	validation-rmse:5.26916
# [30]	validation-rmse:5.26781
# [31]	validation-rmse:5.26822
# [32]	validation-rmse:5.26721
# [33]	validation-rmse:5.26649
# [34]	validation-rmse:5.26715
# [35]	validation-rmse:5.26512
# [36]	validation-rmse:5.26485
# [37]	validation-rmse:5.26461
# [38]	validation-rmse:5.26499
# [39]	validation-rmse:5.26492
# [40]	validation-rmse:5.26549
# [41]	validation-rmse:5.26464
# [42]	validation-rmse:5.26466
# [43]	validation-rmse:5.26474
# [44]	validation-rmse:5.26477
# [45]	validation-rmse:5.26488
# [46]	validation-rmse:5.26553
# [47]	validation-rmse:5.26255
# [48]	validation-rmse:5.26313
# [49]	validation-rmse:5.26309
# [50]	validation-rmse:5.26311
# [51]	validation-rmse:5.26364
# [52]	validation-rmse:5.26420
# [53]	validation-rmse:5.26457
# [54]	validation-rmse:5.26511
# [55]	validation-rmse:5.26432
# [56]	validation-rmse:5.26404
# [57]	validation-rmse:5.26471
#  30%|███       | 3/10 [02:27<05:46, 49.49s/trial, best loss: 5.2063899533766484]
# 2024/09/24 21:47:11 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:47:11] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/24 21:47:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run upset-kite-830 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/e7c1b515653742fe99343a5ca193a9c7.
#
# 2024/09/24 21:47:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:6.61658
# [1]	validation-rmse:5.75110
# [2]	validation-rmse:5.47897
# [3]	validation-rmse:5.38739
# [4]	validation-rmse:5.35091
# [5]	validation-rmse:5.33376
# [6]	validation-rmse:5.32353
# [7]	validation-rmse:5.31344
# [8]	validation-rmse:5.29503
# [9]	validation-rmse:5.29199
# [10]	validation-rmse:5.28583
# [11]	validation-rmse:5.28652
# [12]	validation-rmse:5.28252
# [13]	validation-rmse:5.28111
# [14]	validation-rmse:5.27842
# [15]	validation-rmse:5.27621
# [16]	validation-rmse:5.27341
# [17]	validation-rmse:5.27197
# [18]	validation-rmse:5.27136
# [19]	validation-rmse:5.27112
# [20]	validation-rmse:5.27077
# [21]	validation-rmse:5.27003
# [22]	validation-rmse:5.26858
# [23]	validation-rmse:5.26734
# [24]	validation-rmse:5.26615
# [25]	validation-rmse:5.26448
# [26]	validation-rmse:5.26364
# [27]	validation-rmse:5.26221
# [28]	validation-rmse:5.26232
# [29]	validation-rmse:5.25966
# [30]	validation-rmse:5.25887
# [31]	validation-rmse:5.25760
# [32]	validation-rmse:5.25640
# [33]	validation-rmse:5.25701
# [34]	validation-rmse:5.25450
# [35]	validation-rmse:5.25463
# [36]	validation-rmse:5.25322
# [37]	validation-rmse:5.25302
# [38]	validation-rmse:5.25274
# [39]	validation-rmse:5.25077
# [40]	validation-rmse:5.25037
# [41]	validation-rmse:5.24892
# [42]	validation-rmse:5.24830
# [43]	validation-rmse:5.24687
# [44]	validation-rmse:5.24757
# [45]	validation-rmse:5.24681
# [46]	validation-rmse:5.24626
# [47]	validation-rmse:5.24681
# [48]	validation-rmse:5.24579
# [49]	validation-rmse:5.24545
# [50]	validation-rmse:5.24495
# [51]	validation-rmse:5.24561
# [52]	validation-rmse:5.24454
# [53]	validation-rmse:5.24502
# [54]	validation-rmse:5.24481
# [55]	validation-rmse:5.24349
# [56]	validation-rmse:5.24311
# [57]	validation-rmse:5.24268
# [58]	validation-rmse:5.24204
# [59]	validation-rmse:5.24124
# [60]	validation-rmse:5.24234
# [61]	validation-rmse:5.24136
# [62]	validation-rmse:5.24310
# [63]	validation-rmse:5.24286
# [64]	validation-rmse:5.24302
# [65]	validation-rmse:5.24366
# [66]	validation-rmse:5.24376
# [67]	validation-rmse:5.24028
# [68]	validation-rmse:5.23966
# [69]	validation-rmse:5.23916
# [70]	validation-rmse:5.23843
# [71]	validation-rmse:5.23969
# [72]	validation-rmse:5.23875
# [73]	validation-rmse:5.23876
# [74]	validation-rmse:5.23875
# [75]	validation-rmse:5.23798
# [76]	validation-rmse:5.23814
# [77]	validation-rmse:5.23792
# [78]	validation-rmse:5.23777
# [79]	validation-rmse:5.23844
# [80]	validation-rmse:5.23734
# [81]	validation-rmse:5.23685
# [82]	validation-rmse:5.23664
# [83]	validation-rmse:5.23722
# [84]	validation-rmse:5.23723
# [85]	validation-rmse:5.23725
# [86]	validation-rmse:5.23577
# [87]	validation-rmse:5.23607
# [88]	validation-rmse:5.23556
# [89]	validation-rmse:5.23585
# [90]	validation-rmse:5.23504
# [91]	validation-rmse:5.23522
# [92]	validation-rmse:5.23498
# [93]	validation-rmse:5.23519
# [94]	validation-rmse:5.23494
# [95]	validation-rmse:5.23549
# [96]	validation-rmse:5.23457
# [97]	validation-rmse:5.23521
# [98]	validation-rmse:5.23434
# [99]	validation-rmse:5.23563
#  40%|████      | 4/10 [03:02<04:34, 45.76s/trial, best loss: 5.2063899533766484]
# 2024/09/24 21:47:32 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:47:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/24 21:47:40 INFO mlflow.tracking._tracking_service.client: 🏃 View run exultant-eel-908 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/6d3a350bec7a48fdb574c2d80de4a0e1.
#
# 2024/09/24 21:47:40 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:8.66685
# [1]	validation-rmse:8.26738
# [2]	validation-rmse:7.91612
# [3]	validation-rmse:7.59517
# [4]	validation-rmse:7.31880
# [5]	validation-rmse:7.07262
# [6]	validation-rmse:6.85429
# [7]	validation-rmse:6.65794
# [8]	validation-rmse:6.48635
# [9]	validation-rmse:6.33708
# [10]	validation-rmse:6.20340
# [11]	validation-rmse:6.08721
# [12]	validation-rmse:5.98906
# [13]	validation-rmse:5.90276
# [14]	validation-rmse:5.82862
# [15]	validation-rmse:5.75786
# [16]	validation-rmse:5.70547
# [17]	validation-rmse:5.65208
# [18]	validation-rmse:5.61227
# [19]	validation-rmse:5.57019
# [20]	validation-rmse:5.53912
# [21]	validation-rmse:5.50529
# [22]	validation-rmse:5.48176
# [23]	validation-rmse:5.46047
# [24]	validation-rmse:5.44286
# [25]	validation-rmse:5.42329
# [26]	validation-rmse:5.40970
# [27]	validation-rmse:5.39747
# [28]	validation-rmse:5.38336
# [29]	validation-rmse:5.37321
# [30]	validation-rmse:5.36590
# [31]	validation-rmse:5.35487
# [32]	validation-rmse:5.34801
# [33]	validation-rmse:5.34208
# [34]	validation-rmse:5.33377
# [35]	validation-rmse:5.33043
# [36]	validation-rmse:5.32621
# [37]	validation-rmse:5.32284
# [38]	validation-rmse:5.32073
# [39]	validation-rmse:5.31482
# [40]	validation-rmse:5.31236
# [41]	validation-rmse:5.30720
# [42]	validation-rmse:5.30574
# [43]	validation-rmse:5.30341
# [44]	validation-rmse:5.30235
# [45]	validation-rmse:5.30036
# [46]	validation-rmse:5.29886
# [47]	validation-rmse:5.29726
# [48]	validation-rmse:5.29586
# [49]	validation-rmse:5.29456
# [50]	validation-rmse:5.29296
# [51]	validation-rmse:5.29185
# [52]	validation-rmse:5.29076
# [53]	validation-rmse:5.28975
# [54]	validation-rmse:5.28814
# [55]	validation-rmse:5.28723
# [56]	validation-rmse:5.28604
# [57]	validation-rmse:5.28569
# [58]	validation-rmse:5.28527
# [59]	validation-rmse:5.28453
# [60]	validation-rmse:5.28379
# [61]	validation-rmse:5.28324
# [62]	validation-rmse:5.28268
# [63]	validation-rmse:5.28221
# [64]	validation-rmse:5.28023
# [65]	validation-rmse:5.27957
# [66]	validation-rmse:5.27923
# [67]	validation-rmse:5.27872
# [68]	validation-rmse:5.27824
# [69]	validation-rmse:5.27757
# [70]	validation-rmse:5.27651
# [71]	validation-rmse:5.27632
# [72]	validation-rmse:5.27590
# [73]	validation-rmse:5.27562
# [74]	validation-rmse:5.27557
# [75]	validation-rmse:5.27561
# [76]	validation-rmse:5.27591
# [77]	validation-rmse:5.27483
# [78]	validation-rmse:5.27465
# [79]	validation-rmse:5.27443
# [80]	validation-rmse:5.27396
# [81]	validation-rmse:5.27302
# [82]	validation-rmse:5.27277
# [83]	validation-rmse:5.27252
# [84]	validation-rmse:5.27264
# [85]	validation-rmse:5.27185
# [86]	validation-rmse:5.27160
# [87]	validation-rmse:5.27136
# [88]	validation-rmse:5.27144
# [89]	validation-rmse:5.26995
# [90]	validation-rmse:5.26975
# [91]	validation-rmse:5.26944
# [92]	validation-rmse:5.26854
# [93]	validation-rmse:5.26869
# [94]	validation-rmse:5.26882
# [95]	validation-rmse:5.26802
# [96]	validation-rmse:5.26780
# [97]	validation-rmse:5.26738
# [98]	validation-rmse:5.26715
# [99]	validation-rmse:5.26621
#  50%|█████     | 5/10 [03:29<03:04, 36.96s/trial, best loss: 5.2063899533766484]
# 2024/09/24 21:48:09 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:48:09] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/24 21:48:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run agreeable-fowl-450 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/c484a5555ff24e199c87b16b62c78f92.
#
# 2024/09/24 21:48:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:6.57655
# [1]	validation-rmse:5.72485
# [2]	validation-rmse:5.46341
# [3]	validation-rmse:5.37960
# [4]	validation-rmse:5.35263
# [5]	validation-rmse:5.33511
# [6]	validation-rmse:5.32443
# [7]	validation-rmse:5.32032
# [8]	validation-rmse:5.31126
# [9]	validation-rmse:5.30776
# [10]	validation-rmse:5.30167
# [11]	validation-rmse:5.28600
# [12]	validation-rmse:5.28451
# [13]	validation-rmse:5.28304
# [14]	validation-rmse:5.28217
# [15]	validation-rmse:5.27991
# [16]	validation-rmse:5.27164
# [17]	validation-rmse:5.26868
# [18]	validation-rmse:5.26722
# [19]	validation-rmse:5.26741
# [20]	validation-rmse:5.26236
# [21]	validation-rmse:5.26097
# [22]	validation-rmse:5.25767
# [23]	validation-rmse:5.25656
# [24]	validation-rmse:5.25361
# [25]	validation-rmse:5.25174
# [26]	validation-rmse:5.24752
# [27]	validation-rmse:5.24551
# [28]	validation-rmse:5.24458
# [29]	validation-rmse:5.24519
# [30]	validation-rmse:5.24309
# [31]	validation-rmse:5.24154
# [32]	validation-rmse:5.24006
# [33]	validation-rmse:5.23944
# [34]	validation-rmse:5.23868
# [35]	validation-rmse:5.23793
# [36]	validation-rmse:5.23661
# [37]	validation-rmse:5.23579
# [38]	validation-rmse:5.23535
# [39]	validation-rmse:5.23471
# [40]	validation-rmse:5.23443
# [41]	validation-rmse:5.23316
# [42]	validation-rmse:5.23180
# [43]	validation-rmse:5.23169
# [44]	validation-rmse:5.23110
# [45]	validation-rmse:5.23127
# [46]	validation-rmse:5.23049
# [47]	validation-rmse:5.22993
# [48]	validation-rmse:5.23065
# [49]	validation-rmse:5.23035
# [50]	validation-rmse:5.23000
# [51]	validation-rmse:5.22965
# [52]	validation-rmse:5.22904
# [53]	validation-rmse:5.22738
# [54]	validation-rmse:5.22778
# ...
# [6]	validation-rmse:5.24241
# [7]	validation-rmse:5.22631
# [8]	validation-rmse:5.21551
# [9]	validation-rmse:5.20675
# [10]	validation-rmse:5.20260
# [11]	validation-rmse:5.20190
# [12]	validation-rmse:5.19586
# [13]	validation-rmse:5.19523
# [14]	validation-rmse:5.19093
# [15]	validation-rmse:5.18974
# [16]	validation-rmse:5.18902
# [17]	validation-rmse:5.18911
# [18]	validation-rmse:5.18770
# [19]	validation-rmse:5.18664
# [20]	validation-rmse:5.18593
# [21]	validation-rmse:5.18292
# [22]	validation-rmse:5.18188
# [23]	validation-rmse:5.18118
# [24]	validation-rmse:5.18136
# [25]	validation-rmse:5.18062
# [26]	validation-rmse:5.17966
# [27]	validation-rmse:5.17972
# [28]	validation-rmse:5.17820
# [29]	validation-rmse:5.17720
# [30]	validation-rmse:5.17720
# [31]	validation-rmse:5.17473
# [32]	validation-rmse:5.17477
# [33]	validation-rmse:5.17266
# [34]	validation-rmse:5.17245
# [35]	validation-rmse:5.17145
# [36]	validation-rmse:5.17178
# [37]	validation-rmse:5.17209
# [38]	validation-rmse:5.16975
# [39]	validation-rmse:5.16973
# [40]	validation-rmse:5.16885
# [41]	validation-rmse:5.16868
# [42]	validation-rmse:5.16859
# [43]	validation-rmse:5.16901
# [44]	validation-rmse:5.16883
# [45]	validation-rmse:5.16889
# [46]	validation-rmse:5.16396
# [47]	validation-rmse:5.16390
# [48]	validation-rmse:5.16325
# [49]	validation-rmse:5.16343
# [50]	validation-rmse:5.16384
# [51]	validation-rmse:5.16425
# [52]	validation-rmse:5.16170
# [53]	validation-rmse:5.16201
# [54]	validation-rmse:5.16119
# [55]	validation-rmse:5.16147
# [56]	validation-rmse:5.16045
# [57]	validation-rmse:5.16068
# [58]	validation-rmse:5.16182
# [59]	validation-rmse:5.16256
# [60]	validation-rmse:5.16207
# [61]	validation-rmse:5.16311
# [62]	validation-rmse:5.16284
# [63]	validation-rmse:5.16215
# [64]	validation-rmse:5.16219
# [65]	validation-rmse:5.16258
# [66]	validation-rmse:5.16256
#  80%|████████  | 8/10 [04:27<00:49, 24.64s/trial, best loss: 5.2063899533766484]
# 2024/09/24 21:49:00 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:49:00] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/24 21:49:07 INFO mlflow.tracking._tracking_service.client: 🏃 View run calm-worm-760 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/386863579cf5488585cd4170e40e3993.
#
# 2024/09/24 21:49:07 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:5.82317
# [1]	validation-rmse:5.39900
# [2]	validation-rmse:5.33784
# [3]	validation-rmse:5.32493
# [4]	validation-rmse:5.31448
# [5]	validation-rmse:5.30970
# [6]	validation-rmse:5.30661
# [7]	validation-rmse:5.30205
# [8]	validation-rmse:5.29281
# [9]	validation-rmse:5.29214
# [10]	validation-rmse:5.28805
# [11]	validation-rmse:5.26833
# [12]	validation-rmse:5.26849
# [13]	validation-rmse:5.26638
# [14]	validation-rmse:5.26444
# [15]	validation-rmse:5.26183
# [16]	validation-rmse:5.25696
# [17]	validation-rmse:5.25533
# [18]	validation-rmse:5.25600
# [19]	validation-rmse:5.25302
# [20]	validation-rmse:5.24532
# [21]	validation-rmse:5.24257
# [22]	validation-rmse:5.24028
# [23]	validation-rmse:5.23856
# [24]	validation-rmse:5.24042
# [25]	validation-rmse:5.23545
# [26]	validation-rmse:5.23540
# [27]	validation-rmse:5.23452
# [28]	validation-rmse:5.23450
# [29]	validation-rmse:5.23321
# [30]	validation-rmse:5.23309
# [31]	validation-rmse:5.23425
# [32]	validation-rmse:5.23415
# [33]	validation-rmse:5.23435
# [34]	validation-rmse:5.23431
# [35]	validation-rmse:5.23317
# [36]	validation-rmse:5.23218
# [37]	validation-rmse:5.23089
# [38]	validation-rmse:5.23064
# [39]	validation-rmse:5.23086
# [40]	validation-rmse:5.22934
# [41]	validation-rmse:5.22771
# [42]	validation-rmse:5.22736
# [43]	validation-rmse:5.22728
# [44]	validation-rmse:5.22597
# [45]	validation-rmse:5.22468
# [46]	validation-rmse:5.22474
# [47]	validation-rmse:5.22396
# [48]	validation-rmse:5.22252
# [49]	validation-rmse:5.22279
# [50]	validation-rmse:5.22281
# [51]	validation-rmse:5.22211
# [52]	validation-rmse:5.22201
# [53]	validation-rmse:5.22170
# [54]	validation-rmse:5.21881
# [55]	validation-rmse:5.21807
# [56]	validation-rmse:5.21715
# [57]	validation-rmse:5.21626
# [58]	validation-rmse:5.21492
# [59]	validation-rmse:5.21564
# [60]	validation-rmse:5.21392
# [61]	validation-rmse:5.21382
# [62]	validation-rmse:5.21456
# [63]	validation-rmse:5.21327
# [64]	validation-rmse:5.21411
# [65]	validation-rmse:5.21239
# [66]	validation-rmse:5.21317
# [67]	validation-rmse:5.21349
# [68]	validation-rmse:5.21498
# [69]	validation-rmse:5.21506
# [70]	validation-rmse:5.21395
# [71]	validation-rmse:5.21570
# [72]	validation-rmse:5.21550
# [73]	validation-rmse:5.21655
# [74]	validation-rmse:5.21525
#  90%|█████████ | 9/10 [04:45<00:23, 23.43s/trial, best loss: 5.162562166885411]
# 2024/09/24 21:49:16 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:49:16] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
#
# 2024/09/24 21:49:22 INFO mlflow.tracking._tracking_service.client: 🏃 View run rogue-hawk-422 at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/2aebdfa38ae0481d9be807400620429d.
#
# 2024/09/24 21:49:22 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# 100%|██████████| 10/10 [04:56<00:00, 29.64s/trial, best loss: 5.162562166885411]
# 2024/09/24 21:49:23 INFO mlflow.tracking._tracking_service.client: 🏃 View run Xgboost Hyper-parameter Optimization at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/b0646b40d1c74928a24f63327bce4fa3.
# 2024/09/24 21:49:23 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.
# [0]	validation-rmse:7.16493
# [1]	validation-rmse:6.15681
# [2]	validation-rmse:5.66595
# [3]	validation-rmse:5.43983
# [4]	validation-rmse:5.32676
# [5]	validation-rmse:5.27358
# [6]	validation-rmse:5.24241
# [7]	validation-rmse:5.22631
# [8]	validation-rmse:5.21551
# [9]	validation-rmse:5.20675
# [10]	validation-rmse:5.20260
# [11]	validation-rmse:5.20190
# [12]	validation-rmse:5.19586
# [13]	validation-rmse:5.19523
# [14]	validation-rmse:5.19093
# [15]	validation-rmse:5.18974
# [16]	validation-rmse:5.18902
# [17]	validation-rmse:5.18911
# [18]	validation-rmse:5.18770
# [19]	validation-rmse:5.18664
# [20]	validation-rmse:5.18593
# [21]	validation-rmse:5.18292
# [22]	validation-rmse:5.18188
# [23]	validation-rmse:5.18118
# [24]	validation-rmse:5.18136
# [25]	validation-rmse:5.18062
# [26]	validation-rmse:5.17966
# [27]	validation-rmse:5.17972
# [28]	validation-rmse:5.17820
# [29]	validation-rmse:5.17720
# [30]	validation-rmse:5.17720
# [31]	validation-rmse:5.17473
# [32]	validation-rmse:5.17477
# [33]	validation-rmse:5.17266
# [34]	validation-rmse:5.17245
# [35]	validation-rmse:5.17145
# [36]	validation-rmse:5.17178
# [37]	validation-rmse:5.17209
# [38]	validation-rmse:5.16975
# [39]	validation-rmse:5.16973
# [40]	validation-rmse:5.16885
# [41]	validation-rmse:5.16868
# [42]	validation-rmse:5.16859
# [43]	validation-rmse:5.16901
# [44]	validation-rmse:5.16883
# [45]	validation-rmse:5.16889
# [46]	validation-rmse:5.16396
# [47]	validation-rmse:5.16390
# [48]	validation-rmse:5.16325
# [49]	validation-rmse:5.16343
# [50]	validation-rmse:5.16384
# [51]	validation-rmse:5.16425
# [52]	validation-rmse:5.16170
# [53]	validation-rmse:5.16201
# [54]	validation-rmse:5.16119
# [55]	validation-rmse:5.16147
# [56]	validation-rmse:5.16045
# [57]	validation-rmse:5.16068
# [58]	validation-rmse:5.16182
# [59]	validation-rmse:5.16256
# [60]	validation-rmse:5.16207
# [61]	validation-rmse:5.16311
# [62]	validation-rmse:5.16284
# [63]	validation-rmse:5.16215
# [64]	validation-rmse:5.16219
# [65]	validation-rmse:5.16258
# 2024/09/24 21:49:36 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "c:\proggg\DagsTry\venv\Lib\site-packages\xgboost\core.py:158: UserWarning: [21:49:36] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0015a694724fa8361-1\xgboost\xgboost-ci-windows\src\c_api\c_api.cc:1374: Saving model in the UBJSON format as default.  You can use file extension: `json`, `ubj` or `deprecated` to choose between formats."
# 2024/09/24 21:49:44 INFO mlflow.tracking._tracking_service.client: 🏃 View run Best model ever at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1/runs/886a67edcd6e427cbdf31006b4f8b76b.
# 2024/09/24 21:49:44 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://dagshub.com/luislopez3105/DagsTry.mlflow/#/experiments/1.

# %% [markdown]
# Pero falta todavía registrar dicho modelo en el `model registry`.
